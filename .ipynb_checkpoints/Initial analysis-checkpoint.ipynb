# %%
# %matplotlib inline

import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt

# %%
loandata = pd.read_csv('../data/LoanStats3d.csv',skiprows=[0] ,index_col='id')
# Out:
# C:\Users\New\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
loandata.head()
# Out:
#            member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 68615044  73517819.0    16000.0      16000.0          16000.0   60 months
# 68466066  73355870.0    20200.0      20200.0          20200.0   60 months
# 68565856  73455664.0     9000.0       9000.0           9000.0   36 months
# 68597047  73486873.0    19000.0      19000.0          19000.0   60 months
# 68356421  73246236.0    22400.0      22400.0          22400.0   60 months
#
#          int_rate  installment grade sub_grade            emp_title  \
# id
# 68615044   13.99%       372.21     C        C4     Registered Nurse
# 68466066   18.49%       518.35     D        D5              Manager
# 68565856    9.17%       286.92     B        B2         Truck Driver
# 68597047   14.85%       450.52     C        C5  Application Analyst
# 68356421   12.88%       508.30     C        C2   Executive Director
#
#                     ...             num_tl_90g_dpd_24m num_tl_op_past_12m  \
# id                  ...
# 68615044            ...                            0.0                0.0
# 68466066            ...                            0.0                4.0
# 68565856            ...                            0.0                1.0
# 68597047            ...                            0.0                4.0
# 68356421            ...                            0.0                3.0
#
#           pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies tax_liens  \
# id
# 68615044            73.7             25.0                  0.0       2.0
# 68466066           100.0             25.0                  1.0       0.0
# 68565856           100.0             33.3                  0.0       0.0
# 68597047            94.1            100.0                  0.0       0.0
# 68356421            97.0             25.0                  0.0       0.0
#
#          tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# id
# 68615044        704224.0          112166.0         5100.0
# 68466066         84627.0           43224.0        17800.0
# 68565856         69818.0           14118.0        15500.0
# 68597047         94620.0           48159.0         7500.0
# 68356421        436841.0          184356.0        21000.0
#
#          total_il_high_credit_limit
# id
# 68615044                   124120.0
# 68466066                    64227.0
# 68565856                    16318.0
# 68597047                    36720.0
# 68356421                   191682.0
#
# [5 rows x 110 columns]

# %%
list(loandata.columns.values)
# Out:
# ['member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit']

# %%
loandata.describe(include='all')
# Out:
#            member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count   4.210950e+05  421095.000000  421095.000000    421095.000000
# unique           NaN            NaN            NaN              NaN
# top              NaN            NaN            NaN              NaN
# freq             NaN            NaN            NaN              NaN
# mean    5.759576e+07   15240.285862   15240.285862     15234.156307
# std     1.013358e+07    8571.325901    8571.325901      8567.935724
# min     7.082500e+04    1000.000000    1000.000000       900.000000
# 25%     4.922617e+07    8500.000000    8500.000000      8500.000000
# 50%     5.895358e+07   14000.000000   14000.000000     14000.000000
# 75%     6.604584e+07   20000.000000   20000.000000     20000.000000
# max     7.354484e+07   35000.000000   35000.000000     35000.000000
#
#               term int_rate    installment   grade sub_grade emp_title  \
# count       421095   421095  421095.000000  421095    421095    397221
# unique           2      110            NaN       7        35    120812
# top      36 months    7.89%            NaN       C        C1   Teacher
# freq        283173    20309            NaN  120567     26434      8070
# mean           NaN      NaN     441.868902     NaN       NaN       NaN
# std            NaN      NaN     244.855262     NaN       NaN       NaN
# min            NaN      NaN      30.120000     NaN       NaN       NaN
# 25%            NaN      NaN     263.930000     NaN       NaN       NaN
# 50%            NaN      NaN     385.410000     NaN       NaN       NaN
# 75%            NaN      NaN     578.790000     NaN       NaN       NaN
# max            NaN      NaN    1445.460000     NaN       NaN       NaN
#
#                   ...             num_tl_90g_dpd_24m num_tl_op_past_12m  \
# count             ...                  421095.000000      421095.000000
# unique            ...                            NaN                NaN
# top               ...                            NaN                NaN
# freq              ...                            NaN                NaN
# mean              ...                       0.094318           2.170947
# std               ...                       0.522758           1.853858
# min               ...                       0.000000           0.000000
# 25%               ...                       0.000000           1.000000
# 50%               ...                       0.000000           2.000000
# 75%               ...                       0.000000           3.000000
# max               ...                      39.000000          30.000000
#
#         pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies      tax_liens  \
# count    421095.000000    416856.000000        421095.000000  421095.000000
# unique             NaN              NaN                  NaN            NaN
# top                NaN              NaN                  NaN            NaN
# freq               NaN              NaN                  NaN            NaN
# mean         93.924313        47.527110             0.133188       0.064556
# std           8.875399        36.054458             0.385975       0.444231
# min           0.000000         0.000000             0.000000       0.000000
# 25%          90.900000        15.400000             0.000000       0.000000
# 50%          97.400000        50.000000             0.000000       0.000000
# 75%         100.000000        75.000000             0.000000       0.000000
# max         100.000000       100.000000            11.000000      85.000000
#
#        tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# count     4.210950e+05      4.210950e+05  421095.000000
# unique             NaN               NaN            NaN
# top                NaN               NaN            NaN
# freq               NaN               NaN            NaN
# mean      1.734070e+05      5.222199e+04   21958.208958
# std       1.756722e+05      4.907494e+04   21840.371112
# min       2.500000e+03      0.000000e+00       0.000000
# 25%       5.090900e+04      2.259850e+04    7800.000000
# 50%       1.114050e+05      3.959600e+04   15200.000000
# 75%       2.496290e+05      6.565100e+04   28600.000000
# max       9.999999e+06      2.921551e+06  834300.000000
#
#        total_il_high_credit_limit
# count                4.210950e+05
# unique                        NaN
# top                           NaN
# freq                          NaN
# mean                 4.347865e+04
# std                  4.394271e+04
# min                  0.000000e+00
# 25%                  1.548150e+04
# 50%                  3.297000e+04
# 75%                  5.829900e+04
# max                  2.101913e+06
#
# [11 rows x 110 columns]

# %% [markdown]
# # Data understanding
#
# The reponse variable the learner will try to predict is the final loan_status, whether 'Fully Paid' or 'Charged Off' (i.e. severly delinquent and assess by the creditor as unlikly to be paid).
#
# ## Features to be used
#
# The features I'll consider to use in the learner are:
# * acc_open_past_24mths
# * addr_state
# * all_util
# * annual_inc
# * annual_inc_joint
# * application_type
# * avg_cur_bal
# * bc_open_to_buy
# * bc_util
# * chargeoff_within_12_mths
# * collection_recovery_fee
# * collections_12_mths_ex_med
# * delinq_2yrs
# * delinq_amnt
# * dti
# * dti_joint
# * earliest_cr_line
# * emp_length
# * emp_title
# * fico_range_high
# * fico_range_low
# * funded_amnt
# * funded_amnt_inv
# * grade
# * home_ownership
# * il_util
# * initial_list_status
# * inq_fi
# * inq_last_12m
# * inq_last_6mths
# * installment
# * int_rate
# * last_credit_pull_d
# * last_fico_range_high
# * last_fico_range_low
# * last_pymnt_amnt
# * last_pymnt_d
# * loan_amnt
# * max_bal_bc
# * member_id
# * mo_sin_old_il_acct
# * mo_sin_old_rev_tl_op
# * mo_sin_rcnt_rev_tl_op
# * mo_sin_rcnt_tl
# * mort_acc
# * mths_since_last_delinq
# * mths_since_last_major_derog
# * mths_since_last_record
# * mths_since_rcnt_il
# * mths_since_recent_bc
# * mths_since_recent_bc_dlq
# * mths_since_recent_inq
# * mths_since_recent_revol_delinq
# * num_accts_ever_120_pd
# * num_actv_bc_tl
# * num_actv_rev_tl
# * num_bc_sats
# * num_bc_tl
# * num_il_tl
# * num_op_rev_tl
# * num_rev_accts
# * num_rev_tl_bal_gt_0
# * num_sats
# * num_tl_120dpd_2m
# * num_tl_30dpd
# * num_tl_90g_dpd_24m
# * num_tl_op_past_12m
# * open_acc
# * open_acc_6m
# * open_il_12m
# * open_il_24m
# * open_il_6m
# * open_rv_12m
# * open_rv_24m
# * out_prncp
# * out_prncp_inv
# * pct_tl_nvr_dlq
# * percent_bc_gt_75
# * policy_code
# * pub_rec
# * pub_rec_bankruptcies
# * purpose
# * pymnt_plan
# * recoveries
# * revol_bal
# * revol_util
# * sub_grade
# * tax_liens
# * term
# * tot_coll_amt
# * tot_cur_bal
# * tot_hi_cred_lim
# * total_acc
# * total_bal_ex_mort
# * total_bal_il
# * total_bc_limit
# * total_cu_tl
# * total_il_high_credit_limit
# * total_pymnt
# * total_pymnt_inv
# * total_rec_int
# * total_rec_late_fee
# * total_rec_prncp
# * total_rev_hi_lim
# * verification_status
# * verified_status_joint
#
# The above list of features is prior to any approaches to reduce the number of dimensions

# %%
print loandata.loan_status.value_counts()
# For the project I'll limit the scopr to just looking at loan_status of 'Fully Paid' and 'Charged Off'
# Out:
# Current               363006
# Fully Paid             39008
# Charged Off             7512
# Late (31-120 days)      6233
# In Grace Period         3937
# Late (16-30 days)       1263
# Default                  136
# Name: loan_status, dtype: int64

# %%
narroweddata=loandata[(loandata.loan_status=='Charged Off')|(loandata.loan_status=='Fully Paid')]

# %%
# Check for collinearity between variables
narroweddata.corr(method="pearson")
# Out:
#                                 member_id  loan_amnt  funded_amnt  \
# member_id                        1.000000  -0.002530    -0.002530
# loan_amnt                       -0.002530   1.000000     1.000000
# funded_amnt                     -0.002530   1.000000     1.000000
# funded_amnt_inv                 -0.002841   0.999996     0.999996
# installment                     -0.010670   0.951812     0.951812
# annual_inc                       0.028752   0.277513     0.277513
# dti                              0.002472  -0.005618    -0.005618
# delinq_2yrs                      0.000173  -0.014454    -0.014454
# inq_last_6mths                   0.010560  -0.016250    -0.016250
# mths_since_last_delinq           0.005518  -0.038876    -0.038876
# mths_since_last_record          -0.038108   0.016674     0.016674
# open_acc                         0.006887   0.183864     0.183864
# pub_rec                         -0.003595  -0.106166    -0.106166
# revol_bal                       -0.000231   0.322631     0.322631
# total_acc                        0.003879   0.191719     0.191719
# out_prncp                             NaN        NaN          NaN
# out_prncp_inv                         NaN        NaN          NaN
# total_pymnt                      0.040693   0.811973     0.811973
# total_pymnt_inv                  0.040434   0.811961     0.811961
# total_rec_prncp                  0.078229   0.772227     0.772227
# total_rec_int                   -0.267718   0.632531     0.632531
# total_rec_late_fee              -0.026402   0.051158     0.051158
# recoveries                      -0.117057   0.119583     0.119583
# collection_recovery_fee         -0.119734   0.123606     0.123606
# last_pymnt_amnt                  0.136399   0.686249     0.686249
# collections_12_mths_ex_med       0.009106  -0.023302    -0.023302
# mths_since_last_major_derog      0.014263  -0.008617    -0.008617
# policy_code                           NaN        NaN          NaN
# annual_inc_joint                -0.211421   0.746576     0.746576
# dti_joint                       -0.074538  -0.252830    -0.252830
# ...                                   ...        ...          ...
# mo_sin_old_rev_tl_op             0.004233   0.152190     0.152190
# mo_sin_rcnt_rev_tl_op            0.002151   0.047347     0.047347
# mo_sin_rcnt_tl                  -0.008529   0.024864     0.024864
# mort_acc                        -0.001540   0.208825     0.208825
# mths_since_recent_bc             0.002559   0.028136     0.028136
# mths_since_recent_bc_dlq        -0.005376  -0.050895    -0.050895
# mths_since_recent_inq           -0.029288  -0.016601    -0.016601
# mths_since_recent_revol_delinq  -0.001725  -0.047142    -0.047142
# num_accts_ever_120_pd           -0.013384  -0.050185    -0.050185
# num_actv_bc_tl                  -0.022986   0.212130     0.212130
# num_actv_rev_tl                 -0.030412   0.162476     0.162476
# num_bc_sats                      0.014204   0.218255     0.218255
# num_bc_tl                       -0.009288   0.192565     0.192565
# num_il_tl                        0.005069   0.069070     0.069070
# num_op_rev_tl                    0.007471   0.171949     0.171949
# num_rev_accts                    0.001797   0.161034     0.161034
# num_rev_tl_bal_gt_0             -0.035118   0.167390     0.167390
# num_sats                         0.006254   0.185394     0.185394
# num_tl_120dpd_2m                 0.005593   0.001292     0.001292
# num_tl_30dpd                     0.007261   0.010025     0.010025
# num_tl_90g_dpd_24m              -0.002855  -0.032758    -0.032758
# num_tl_op_past_12m               0.042266  -0.016015    -0.016015
# pct_tl_nvr_dlq                   0.001877   0.097245     0.097245
# percent_bc_gt_75                -0.072368   0.030067     0.030067
# pub_rec_bankruptcies             0.002380  -0.133297    -0.133297
# tax_liens                       -0.000934   0.004571     0.004571
# tot_hi_cred_lim                  0.030925   0.348714     0.348714
# total_bal_ex_mort                0.011623   0.287205     0.287205
# total_bc_limit                   0.037063   0.382689     0.382689
# total_il_high_credit_limit       0.019790   0.198403     0.198403
#
#                                 funded_amnt_inv  installment  annual_inc  \
# member_id                             -0.002841    -0.010670    0.028752
# loan_amnt                              0.999996     0.951812    0.277513
# funded_amnt                            0.999996     0.951812    0.277513
# funded_amnt_inv                        1.000000     0.951809    0.277534
# installment                            0.951809     1.000000    0.267627
# annual_inc                             0.277534     0.267627    1.000000
# dti                                   -0.005632    -0.005940   -0.035974
# delinq_2yrs                           -0.014466    -0.006697    0.051586
# inq_last_6mths                        -0.016312     0.015391    0.020460
# mths_since_last_delinq                -0.038841    -0.038498   -0.040357
# mths_since_last_record                 0.016746     0.003620   -0.080569
# open_acc                               0.183890     0.170592    0.095147
# pub_rec                               -0.106133    -0.088545   -0.022604
# revol_bal                              0.322600     0.306669    0.242605
# total_acc                              0.191764     0.172041    0.132753
# out_prncp                                   NaN          NaN         NaN
# out_prncp_inv                               NaN          NaN         NaN
# total_pymnt                            0.811990     0.771271    0.251492
# total_pymnt_inv                        0.811985     0.771259    0.251507
# total_rec_prncp                        0.772236     0.733567    0.246762
# total_rec_int                          0.632611     0.597873    0.140071
# total_rec_late_fee                     0.051126     0.060759    0.007704
# recoveries                             0.119608     0.116955    0.011265
# collection_recovery_fee                0.123625     0.123058    0.008157
# last_pymnt_amnt                        0.686226     0.636804    0.220678
# collections_12_mths_ex_med            -0.023347    -0.018445   -0.008272
# mths_since_last_major_derog           -0.008606    -0.008821   -0.028886
# policy_code                                 NaN          NaN         NaN
# annual_inc_joint                       0.747255     0.639630    0.813008
# dti_joint                             -0.254472    -0.409891   -0.339951
# ...                                         ...          ...         ...
# mo_sin_old_rev_tl_op                   0.152243     0.133572    0.109855
# mo_sin_rcnt_rev_tl_op                  0.047372     0.029708    0.037267
# mo_sin_rcnt_tl                         0.024878     0.009948   -0.011729
# mort_acc                               0.208857     0.185491    0.183866
# mths_since_recent_bc                   0.028168     0.012747    0.029442
# mths_since_recent_bc_dlq              -0.050889    -0.040954   -0.034580
# mths_since_recent_inq                 -0.016545    -0.034654   -0.039215
# mths_since_recent_revol_delinq        -0.047096    -0.040093   -0.029159
# num_accts_ever_120_pd                 -0.050211    -0.038022    0.018476
# num_actv_bc_tl                         0.212118     0.208067    0.076179
# num_actv_rev_tl                        0.162456     0.165164    0.045604
# num_bc_sats                            0.218273     0.207091    0.088971
# num_bc_tl                              0.192603     0.177049    0.097264
# num_il_tl                              0.069091     0.056068    0.073152
# num_op_rev_tl                          0.171974     0.163605    0.054002
# num_rev_accts                          0.161071     0.149701    0.075693
# num_rev_tl_bal_gt_0                    0.167375     0.168263    0.045902
# num_sats                               0.185418     0.171654    0.095506
# num_tl_120dpd_2m                       0.001284     0.002982    0.008802
# num_tl_30dpd                           0.010032     0.012382    0.009694
# num_tl_90g_dpd_24m                    -0.032763    -0.025421    0.007777
# num_tl_op_past_12m                    -0.016078     0.013948    0.037459
# pct_tl_nvr_dlq                         0.097294     0.079408   -0.011675
# percent_bc_gt_75                       0.029989     0.042157   -0.014674
# pub_rec_bankruptcies                  -0.133266    -0.119215   -0.049460
# tax_liens                              0.004580     0.012932    0.028365
# tot_hi_cred_lim                        0.348755     0.318120    0.363890
# total_bal_ex_mort                      0.287205     0.270312    0.280921
# total_bc_limit                         0.382759     0.346625    0.236102
# total_il_high_credit_limit             0.198419     0.182953    0.226595
#
#                                      dti  delinq_2yrs  inq_last_6mths  \
# member_id                       0.002472     0.000173        0.010560
# loan_amnt                      -0.005618    -0.014454       -0.016250
# funded_amnt                    -0.005618    -0.014454       -0.016250
# funded_amnt_inv                -0.005632    -0.014466       -0.016312
# installment                    -0.005940    -0.006697        0.015391
# annual_inc                     -0.035974     0.051586        0.020460
# dti                             1.000000     0.004567        0.001102
# delinq_2yrs                     0.004567     1.000000        0.026516
# inq_last_6mths                  0.001102     0.026516        1.000000
# mths_since_last_delinq         -0.006099    -0.550253        0.035815
# mths_since_last_record          0.087082    -0.099567       -0.096020
# open_acc                        0.047213     0.031322        0.165552
# pub_rec                        -0.013383    -0.012018        0.107488
# revol_bal                       0.021006    -0.027412       -0.011585
# total_acc                       0.034266     0.104855        0.165100
# out_prncp                            NaN          NaN             NaN
# out_prncp_inv                        NaN          NaN             NaN
# total_pymnt                    -0.016837    -0.020679       -0.035901
# total_pymnt_inv                -0.016848    -0.020683       -0.035943
# total_rec_prncp                -0.018938    -0.023094       -0.043219
# total_rec_int                   0.008267     0.010203        0.037694
# total_rec_late_fee              0.001850     0.014260        0.008503
# recoveries                      0.007702     0.007054        0.027225
# collection_recovery_fee         0.008400     0.006794        0.029310
# last_pymnt_amnt                -0.015323    -0.025889       -0.031014
# collections_12_mths_ex_med     -0.001246     0.067387        0.013867
# mths_since_last_major_derog    -0.009870    -0.413634        0.045644
# policy_code                          NaN          NaN             NaN
# annual_inc_joint               -0.382433    -0.379951       -0.556252
# dti_joint                       0.505343     0.503270        0.228813
# ...                                  ...          ...             ...
# mo_sin_old_rev_tl_op            0.018537     0.077463        0.011018
# mo_sin_rcnt_rev_tl_op          -0.007714     0.040722       -0.210603
# mo_sin_rcnt_tl                 -0.018986     0.033780       -0.222161
# mort_acc                       -0.015048     0.062282        0.015718
# mths_since_recent_bc            0.008319     0.056551       -0.153632
# mths_since_recent_bc_dlq       -0.011977    -0.480689        0.062848
# mths_since_recent_inq           0.000554    -0.022448       -0.533885
# mths_since_recent_revol_delinq -0.010022    -0.507787        0.057418
# num_accts_ever_120_pd          -0.011827     0.186213        0.056495
# num_actv_bc_tl                  0.026177    -0.050365        0.106490
# num_actv_rev_tl                 0.046218    -0.014756        0.168404
# num_bc_sats                     0.011725    -0.031697        0.168318
# num_bc_tl                       0.007049     0.027692        0.151125
# num_il_tl                       0.039518     0.069608        0.059080
# num_op_rev_tl                   0.029122    -0.010291        0.179237
# num_rev_accts                   0.019178     0.073160        0.184770
# num_rev_tl_bal_gt_0             0.046896    -0.021010        0.143465
# num_sats                        0.047162     0.028214        0.160825
# num_tl_120dpd_2m               -0.002521     0.038989        0.003569
# num_tl_30dpd                    0.001901     0.097894       -0.001364
# num_tl_90g_dpd_24m              0.003761     0.673556        0.043904
# num_tl_op_past_12m              0.012219    -0.030437        0.358445
# pct_tl_nvr_dlq                  0.016467    -0.436441       -0.050786
# percent_bc_gt_75                0.030461    -0.012628       -0.074495
# pub_rec_bankruptcies           -0.009728    -0.035881        0.128755
# tax_liens                      -0.007173     0.019014        0.014966
# tot_hi_cred_lim                -0.006291     0.053006       -0.002999
# total_bal_ex_mort               0.048534     0.020638        0.022700
# total_bc_limit                 -0.002699    -0.074476        0.006420
# total_il_high_credit_limit      0.055440     0.048865        0.031255
#
#                                 mths_since_last_delinq  \
# member_id                                     0.005518
# loan_amnt                                    -0.038876
# funded_amnt                                  -0.038876
# funded_amnt_inv                              -0.038841
# installment                                  -0.038498
# annual_inc                                   -0.040357
# dti                                          -0.006099
# delinq_2yrs                                  -0.550253
# inq_last_6mths                                0.035815
# mths_since_last_delinq                        1.000000
# mths_since_last_record                       -0.030492
# open_acc                                     -0.027738
# pub_rec                                       0.123392
# revol_bal                                    -0.037668
# total_acc                                    -0.023523
# out_prncp                                          NaN
# out_prncp_inv                                      NaN
# total_pymnt                                  -0.015545
# total_pymnt_inv                              -0.015521
# total_rec_prncp                              -0.011848
# total_rec_int                                -0.030791
# total_rec_late_fee                           -0.018748
# recoveries                                   -0.015358
# collection_recovery_fee                      -0.014923
# last_pymnt_amnt                               0.000180
# collections_12_mths_ex_med                   -0.047059
# mths_since_last_major_derog                   0.704703
# policy_code                                        NaN
# annual_inc_joint                              0.100044
# dti_joint                                    -0.551235
# ...                                                ...
# mo_sin_old_rev_tl_op                         -0.032836
# mo_sin_rcnt_rev_tl_op                        -0.080257
# mo_sin_rcnt_tl                               -0.072317
# mort_acc                                     -0.054840
# mths_since_recent_bc                         -0.092023
# mths_since_recent_bc_dlq                      0.777630
# mths_since_recent_inq                        -0.012871
# mths_since_recent_revol_delinq                0.868516
# num_accts_ever_120_pd                         0.027699
# num_actv_bc_tl                                0.038273
# num_actv_rev_tl                               0.033658
# num_bc_sats                                   0.036815
# num_bc_tl                                     0.032120
# num_il_tl                                    -0.010173
# num_op_rev_tl                                 0.003954
# num_rev_accts                                -0.007237
# num_rev_tl_bal_gt_0                           0.025562
# num_sats                                     -0.027022
# num_tl_120dpd_2m                             -0.062091
# num_tl_30dpd                                 -0.129143
# num_tl_90g_dpd_24m                           -0.226340
# num_tl_op_past_12m                            0.106109
# pct_tl_nvr_dlq                                0.175305
# percent_bc_gt_75                              0.008890
# pub_rec_bankruptcies                          0.167358
# tax_liens                                    -0.000507
# tot_hi_cred_lim                              -0.104399
# total_bal_ex_mort                            -0.040506
# total_bc_limit                               -0.034418
# total_il_high_credit_limit                   -0.041653
#
#                                            ...              \
# member_id                                  ...
# loan_amnt                                  ...
# funded_amnt                                ...
# funded_amnt_inv                            ...
# installment                                ...
# annual_inc                                 ...
# dti                                        ...
# delinq_2yrs                                ...
# inq_last_6mths                             ...
# mths_since_last_delinq                     ...
# mths_since_last_record                     ...
# open_acc                                   ...
# pub_rec                                    ...
# revol_bal                                  ...
# total_acc                                  ...
# out_prncp                                  ...
# out_prncp_inv                              ...
# total_pymnt                                ...
# total_pymnt_inv                            ...
# total_rec_prncp                            ...
# total_rec_int                              ...
# total_rec_late_fee                         ...
# recoveries                                 ...
# collection_recovery_fee                    ...
# last_pymnt_amnt                            ...
# collections_12_mths_ex_med                 ...
# mths_since_last_major_derog                ...
# policy_code                                ...
# annual_inc_joint                           ...
# dti_joint                                  ...
# ...                                        ...
# mo_sin_old_rev_tl_op                       ...
# mo_sin_rcnt_rev_tl_op                      ...
# mo_sin_rcnt_tl                             ...
# mort_acc                                   ...
# mths_since_recent_bc                       ...
# mths_since_recent_bc_dlq                   ...
# mths_since_recent_inq                      ...
# mths_since_recent_revol_delinq             ...
# num_accts_ever_120_pd                      ...
# num_actv_bc_tl                             ...
# num_actv_rev_tl                            ...
# num_bc_sats                                ...
# num_bc_tl                                  ...
# num_il_tl                                  ...
# num_op_rev_tl                              ...
# num_rev_accts                              ...
# num_rev_tl_bal_gt_0                        ...
# num_sats                                   ...
# num_tl_120dpd_2m                           ...
# num_tl_30dpd                               ...
# num_tl_90g_dpd_24m                         ...
# num_tl_op_past_12m                         ...
# pct_tl_nvr_dlq                             ...
# percent_bc_gt_75                           ...
# pub_rec_bankruptcies                       ...
# tax_liens                                  ...
# tot_hi_cred_lim                            ...
# total_bal_ex_mort                          ...
# total_bc_limit                             ...
# total_il_high_credit_limit                 ...
#
#                                 num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# member_id                                -0.002855            0.042266
# loan_amnt                                -0.032758           -0.016015
# funded_amnt                              -0.032758           -0.016015
# funded_amnt_inv                          -0.032763           -0.016078
# installment                              -0.025421            0.013948
# annual_inc                                0.007777            0.037459
# dti                                       0.003761            0.012219
# delinq_2yrs                               0.673556           -0.030437
# inq_last_6mths                            0.043904            0.358445
# mths_since_last_delinq                   -0.226340            0.106109
# mths_since_last_record                   -0.104771           -0.053942
# open_acc                                 -0.001801            0.367224
# pub_rec                                   0.022254            0.105095
# revol_bal                                -0.039022           -0.028170
# total_acc                                 0.068086            0.349549
# out_prncp                                      NaN                 NaN
# out_prncp_inv                                  NaN                 NaN
# total_pymnt                              -0.032331           -0.024823
# total_pymnt_inv                          -0.032330           -0.024873
# total_rec_prncp                          -0.033036           -0.029269
# total_rec_int                            -0.007242            0.029068
# total_rec_late_fee                        0.007600            0.002735
# recoveries                                0.001460            0.006273
# collection_recovery_fee                   0.002302            0.008682
# last_pymnt_amnt                          -0.033205           -0.012921
# collections_12_mths_ex_med                0.104712            0.006347
# mths_since_last_major_derog              -0.442347            0.092069
# policy_code                                    NaN                 NaN
# annual_inc_joint                         -0.379951            0.156142
# dti_joint                                 0.503270           -0.297484
# ...                                            ...                 ...
# mo_sin_old_rev_tl_op                      0.035370            0.004497
# mo_sin_rcnt_rev_tl_op                     0.015173           -0.394886
# mo_sin_rcnt_tl                            0.011842           -0.466021
# mort_acc                                  0.033970            0.046161
# mths_since_recent_bc                      0.018643           -0.290215
# mths_since_recent_bc_dlq                 -0.168839            0.129752
# mths_since_recent_inq                    -0.025434           -0.266934
# mths_since_recent_revol_delinq           -0.152004            0.118094
# num_accts_ever_120_pd                     0.267689            0.080860
# num_actv_bc_tl                           -0.035068            0.166635
# num_actv_rev_tl                          -0.015021            0.263723
# num_bc_sats                              -0.003828            0.246519
# num_bc_tl                                 0.024919            0.253396
# num_il_tl                                 0.055235            0.194191
# num_op_rev_tl                            -0.033196            0.361575
# num_rev_accts                             0.040105            0.324408
# num_rev_tl_bal_gt_0                      -0.029705            0.250730
# num_sats                                 -0.005337            0.364997
# num_tl_120dpd_2m                          0.071649           -0.004342
# num_tl_30dpd                              0.006127           -0.013319
# num_tl_90g_dpd_24m                        1.000000            0.003646
# num_tl_op_past_12m                        0.003646            1.000000
# pct_tl_nvr_dlq                           -0.277052            0.016513
# percent_bc_gt_75                         -0.014355           -0.168384
# pub_rec_bankruptcies                      0.023247            0.122846
# tax_liens                                 0.003824            0.010707
# tot_hi_cred_lim                          -0.004697            0.048075
# total_bal_ex_mort                        -0.000764            0.100590
# total_bc_limit                           -0.062948            0.037993
# total_il_high_credit_limit                0.017692            0.122771
#
#                                 pct_tl_nvr_dlq  percent_bc_gt_75  \
# member_id                             0.001877         -0.072368
# loan_amnt                             0.097245          0.030067
# funded_amnt                           0.097245          0.030067
# funded_amnt_inv                       0.097294          0.029989
# installment                           0.079408          0.042157
# annual_inc                           -0.011675         -0.014674
# dti                                   0.016467          0.030461
# delinq_2yrs                          -0.436441         -0.012628
# inq_last_6mths                       -0.050786         -0.074495
# mths_since_last_delinq                0.175305          0.008890
# mths_since_last_record                0.220480          0.079071
# open_acc                              0.121052         -0.086057
# pub_rec                              -0.066071         -0.065087
# revol_bal                             0.116758          0.136189
# total_acc                             0.020854         -0.085077
# out_prncp                                  NaN               NaN
# out_prncp_inv                              NaN               NaN
# total_pymnt                           0.077121         -0.015152
# total_pymnt_inv                       0.077155         -0.015221
# total_rec_prncp                       0.077060         -0.030859
# total_rec_int                         0.023480          0.118054
# total_rec_late_fee                   -0.009146          0.024354
# recoveries                            0.011647          0.041695
# collection_recovery_fee               0.010490          0.045316
# last_pymnt_amnt                       0.066969         -0.019124
# collections_12_mths_ex_med           -0.044780         -0.026914
# mths_since_last_major_derog           0.111619          0.019471
# policy_code                                NaN               NaN
# annual_inc_joint                      0.098652          0.029449
# dti_joint                             0.127158         -0.021879
# ...                                        ...               ...
# mo_sin_old_rev_tl_op                 -0.096573         -0.007341
# mo_sin_rcnt_rev_tl_op                -0.034590          0.114809
# mo_sin_rcnt_tl                       -0.031461          0.108755
# mort_acc                             -0.048239         -0.007400
# mths_since_recent_bc                 -0.051589          0.133530
# mths_since_recent_bc_dlq              0.069895          0.003916
# mths_since_recent_inq                 0.025534          0.074076
# mths_since_recent_revol_delinq        0.078867          0.007566
# num_accts_ever_120_pd                -0.558323         -0.048084
# num_actv_bc_tl                        0.123849          0.078418
# num_actv_rev_tl                       0.080224          0.128592
# num_bc_sats                           0.118258         -0.150441
# num_bc_tl                             0.034740         -0.164060
# num_il_tl                             0.025170          0.014422
# num_op_rev_tl                         0.136826         -0.137529
# num_rev_accts                         0.022159         -0.132243
# num_rev_tl_bal_gt_0                   0.099605          0.136136
# num_sats                              0.125576         -0.085837
# num_tl_120dpd_2m                     -0.025931         -0.013078
# num_tl_30dpd                         -0.038449         -0.025425
# num_tl_90g_dpd_24m                   -0.277052         -0.014355
# num_tl_op_past_12m                    0.016513         -0.168384
# pct_tl_nvr_dlq                        1.000000         -0.002893
# percent_bc_gt_75                     -0.002893          1.000000
# pub_rec_bankruptcies                 -0.017376         -0.067739
# tax_liens                            -0.040381         -0.016069
# tot_hi_cred_lim                       0.035231          0.001889
# total_bal_ex_mort                     0.080227          0.074838
# total_bc_limit                        0.220507         -0.185848
# total_il_high_credit_limit            0.029062          0.017922
#
#                                 pub_rec_bankruptcies  tax_liens  \
# member_id                                   0.002380  -0.000934
# loan_amnt                                  -0.133297   0.004571
# funded_amnt                                -0.133297   0.004571
# funded_amnt_inv                            -0.133266   0.004580
# installment                                -0.119215   0.012932
# annual_inc                                 -0.049460   0.028365
# dti                                        -0.009728  -0.007173
# delinq_2yrs                                -0.035881   0.019014
# inq_last_6mths                              0.128755   0.014966
# mths_since_last_delinq                      0.167358  -0.000507
# mths_since_last_record                      0.157853  -0.254059
# open_acc                                   -0.026257  -0.010090
# pub_rec                                     0.714093   0.616285
# revol_bal                                  -0.136531  -0.021124
# total_acc                                   0.073046  -0.024386
# out_prncp                                        NaN        NaN
# out_prncp_inv                                    NaN        NaN
# total_pymnt                                -0.105961  -0.009762
# total_pymnt_inv                            -0.105943  -0.009760
# total_rec_prncp                            -0.103560  -0.012265
# total_rec_int                              -0.059281   0.012226
# total_rec_late_fee                         -0.008499   0.010032
# recoveries                                 -0.009916   0.011614
# collection_recovery_fee                    -0.008867   0.012650
# last_pymnt_amnt                            -0.086621  -0.015251
# collections_12_mths_ex_med                  0.002348   0.025726
# mths_since_last_major_derog                 0.151021   0.010799
# policy_code                                      NaN        NaN
# annual_inc_joint                            0.161632        NaN
# dti_joint                                  -0.438843        NaN
# ...                                              ...        ...
# mo_sin_old_rev_tl_op                        0.075183   0.006715
# mo_sin_rcnt_rev_tl_op                      -0.089576  -0.001437
# mo_sin_rcnt_tl                             -0.080580  -0.006995
# mort_acc                                    0.035580  -0.002309
# mths_since_recent_bc                       -0.061466  -0.000284
# mths_since_recent_bc_dlq                    0.188273   0.015706
# mths_since_recent_inq                      -0.082349  -0.009896
# mths_since_recent_revol_delinq              0.183652   0.005614
# num_accts_ever_120_pd                       0.007962   0.020491
# num_actv_bc_tl                             -0.072878   0.006752
# num_actv_rev_tl                            -0.014299   0.001181
# num_bc_sats                                -0.037465  -0.004272
# num_bc_tl                                   0.051869  -0.017432
# num_il_tl                                   0.005668  -0.012176
# num_op_rev_tl                               0.005604  -0.005092
# num_rev_accts                               0.094077  -0.024677
# num_rev_tl_bal_gt_0                        -0.031693   0.001696
# num_sats                                   -0.034933  -0.009895
# num_tl_120dpd_2m                            0.000248  -0.004270
# num_tl_30dpd                               -0.015135   0.007430
# num_tl_90g_dpd_24m                          0.023247   0.003824
# num_tl_op_past_12m                          0.122846   0.010707
# pct_tl_nvr_dlq                             -0.017376  -0.040381
# percent_bc_gt_75                           -0.067739  -0.016069
# pub_rec_bankruptcies                        1.000000   0.029577
# tax_liens                                   0.029577   1.000000
# tot_hi_cred_lim                            -0.130168   0.004436
# total_bal_ex_mort                          -0.092946  -0.004632
# total_bc_limit                             -0.176617  -0.030227
# total_il_high_credit_limit                 -0.040594   0.007822
#
#                                 tot_hi_cred_lim  total_bal_ex_mort  \
# member_id                              0.030925           0.011623
# loan_amnt                              0.348714           0.287205
# funded_amnt                            0.348714           0.287205
# funded_amnt_inv                        0.348755           0.287205
# installment                            0.318120           0.270312
# annual_inc                             0.363890           0.280921
# dti                                   -0.006291           0.048534
# delinq_2yrs                            0.053006           0.020638
# inq_last_6mths                        -0.002999           0.022700
# mths_since_last_delinq                -0.104399          -0.040506
# mths_since_last_record                 0.017725          -0.001155
# open_acc                               0.258343           0.376616
# pub_rec                               -0.098631          -0.079891
# revol_bal                              0.478321           0.521921
# total_acc                              0.299721           0.402944
# out_prncp                                   NaN                NaN
# out_prncp_inv                               NaN                NaN
# total_pymnt                            0.341304           0.239651
# total_pymnt_inv                        0.341342           0.239655
# total_rec_prncp                        0.337557           0.230022
# total_rec_int                          0.180111           0.173182
# total_rec_late_fee                     0.000231           0.010219
# recoveries                            -0.007260           0.025426
# collection_recovery_fee               -0.007905           0.026929
# last_pymnt_amnt                        0.310080           0.209154
# collections_12_mths_ex_med            -0.012103          -0.016915
# mths_since_last_major_derog           -0.056366          -0.028266
# policy_code                                 NaN                NaN
# annual_inc_joint                       0.456085           0.544159
# dti_joint                             -0.225400           0.368294
# ...                                         ...                ...
# mo_sin_old_rev_tl_op                   0.205339           0.092896
# mo_sin_rcnt_rev_tl_op                  0.043978           0.021958
# mo_sin_rcnt_tl                        -0.038461          -0.069429
# mort_acc                               0.509954           0.126996
# mths_since_recent_bc                   0.054754           0.026897
# mths_since_recent_bc_dlq              -0.072479          -0.032137
# mths_since_recent_inq                 -0.046808          -0.039391
# mths_since_recent_revol_delinq        -0.071289          -0.031444
# num_accts_ever_120_pd                 -0.000868          -0.003453
# num_actv_bc_tl                         0.126976           0.141408
# num_actv_rev_tl                        0.115206           0.134888
# num_bc_sats                            0.153145           0.121662
# num_bc_tl                              0.162970           0.108071
# num_il_tl                              0.162510           0.499914
# num_op_rev_tl                          0.130836           0.115868
# num_rev_accts                          0.160541           0.105483
# num_rev_tl_bal_gt_0                    0.117462           0.142711
# num_sats                               0.259325           0.378270
# num_tl_120dpd_2m                       0.006842          -0.001204
# num_tl_30dpd                           0.029427           0.012231
# num_tl_90g_dpd_24m                    -0.004697          -0.000764
# num_tl_op_past_12m                     0.048075           0.100590
# pct_tl_nvr_dlq                         0.035231           0.080227
# percent_bc_gt_75                       0.001889           0.074838
# pub_rec_bankruptcies                  -0.130168          -0.092946
# tax_liens                              0.004436          -0.004632
# tot_hi_cred_lim                        1.000000           0.511067
# total_bal_ex_mort                      0.511067           1.000000
# total_bc_limit                         0.401593           0.277168
# total_il_high_credit_limit             0.374646           0.860016
#
#                                 total_bc_limit  total_il_high_credit_limit
# member_id                             0.037063                    0.019790
# loan_amnt                             0.382689                    0.198403
# funded_amnt                           0.382689                    0.198403
# funded_amnt_inv                       0.382759                    0.198419
# installment                           0.346625                    0.182953
# annual_inc                            0.236102                    0.226595
# dti                                  -0.002699                    0.055440
# delinq_2yrs                          -0.074476                    0.048865
# inq_last_6mths                        0.006420                    0.031255
# mths_since_last_delinq               -0.034418                   -0.041653
# mths_since_last_record               -0.001130                   -0.003588
# open_acc                              0.339278                    0.338585
# pub_rec                              -0.164524                   -0.029784
# revol_bal                             0.478696                    0.092445
# total_acc                             0.247069                    0.399744
# out_prncp                                  NaN                         NaN
# out_prncp_inv                              NaN                         NaN
# total_pymnt                           0.354941                    0.162219
# total_pymnt_inv                       0.355002                    0.162232
# total_rec_prncp                       0.355837                    0.155284
# total_rec_int                         0.128973                    0.118407
# total_rec_late_fee                   -0.007347                    0.006445
# recoveries                            0.008210                    0.021252
# collection_recovery_fee               0.001633                    0.022465
# last_pymnt_amnt                       0.308627                    0.145137
# collections_12_mths_ex_med           -0.031471                   -0.004195
# mths_since_last_major_derog          -0.013389                   -0.027555
# policy_code                                NaN                         NaN
# annual_inc_joint                      0.678657                    0.469787
# dti_joint                             0.131043                    0.404564
# ...                                        ...                         ...
# mo_sin_old_rev_tl_op                  0.247980                    0.014434
# mo_sin_rcnt_rev_tl_op                -0.024941                    0.013038
# mo_sin_rcnt_tl                       -0.001487                   -0.098903
# mort_acc                              0.186554                    0.082223
# mths_since_recent_bc                 -0.084775                    0.009373
# mths_since_recent_bc_dlq             -0.098960                   -0.019952
# mths_since_recent_inq                -0.002837                   -0.049152
# mths_since_recent_revol_delinq       -0.089188                   -0.022888
# num_accts_ever_120_pd                -0.133616                    0.032639
# num_actv_bc_tl                        0.446752                    0.020904
# num_actv_rev_tl                       0.260952                    0.017166
# num_bc_sats                           0.573760                    0.023823
# num_bc_tl                             0.466751                    0.039083
# num_il_tl                            -0.029591                    0.581574
# num_op_rev_tl                         0.401651                    0.029593
# num_rev_accts                         0.335118                    0.041620
# num_rev_tl_bal_gt_0                   0.264064                    0.022189
# num_sats                              0.341530                    0.340255
# num_tl_120dpd_2m                     -0.003386                   -0.002013
# num_tl_30dpd                          0.012755                    0.009632
# num_tl_90g_dpd_24m                   -0.062948                    0.017692
# num_tl_op_past_12m                    0.037993                    0.122771
# pct_tl_nvr_dlq                        0.220507                    0.029062
# percent_bc_gt_75                     -0.185848                    0.017922
# pub_rec_bankruptcies                 -0.176617                   -0.040594
# tax_liens                            -0.030227                    0.007822
# tot_hi_cred_lim                       0.401593                    0.374646
# total_bal_ex_mort                     0.277168                    0.860016
# total_bc_limit                        1.000000                    0.090352
# total_il_high_credit_limit            0.090352                    1.000000
#
# [85 rows x 85 columns]

# %% [markdown]
# ## Some visualisations

# %%
#loandata.boxplot(column='loan_amnt',by='loan_status')
narroweddata.boxplot(column='loan_amnt',by='loan_status')

# We can observe that loans that resulted in being charged off had a higher median loan amount

# %%
narroweddata.boxplot(column='annual_inc',by='loan_status')

# Hard to see, but it looks like annual income would be a good predictor to include
# Need to find a way to make the y a log scale

# %%
#
narroweddata.int_rate = pd.Series(narroweddata.int_rate).str.replace('%', '').astype(float)
narroweddata.boxplot(column='int_rate',by='loan_status')

# As this boxplot shows, higher interest rates would make a loan more expensive to service
# Out:
# C:\Users\New\Anaconda2\lib\site-packages\pandas\core\generic.py:2698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
