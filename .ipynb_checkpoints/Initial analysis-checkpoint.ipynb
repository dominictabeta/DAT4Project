# %%
# %matplotlib inline

import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
import random

# %%
loandata = pd.read_csv('../data/LoanStats3d.csv',skiprows=[0] ,index_col='id')
# Out:
# C:\Users\New\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
loandata.head()
# Out:
#            member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 68615044  73517819.0    16000.0      16000.0          16000.0   60 months
# 68466066  73355870.0    20200.0      20200.0          20200.0   60 months
# 68565856  73455664.0     9000.0       9000.0           9000.0   36 months
# 68597047  73486873.0    19000.0      19000.0          19000.0   60 months
# 68356421  73246236.0    22400.0      22400.0          22400.0   60 months
#
#          int_rate  installment grade sub_grade            emp_title  \
# id
# 68615044   13.99%       372.21     C        C4     Registered Nurse
# 68466066   18.49%       518.35     D        D5              Manager
# 68565856    9.17%       286.92     B        B2         Truck Driver
# 68597047   14.85%       450.52     C        C5  Application Analyst
# 68356421   12.88%       508.30     C        C2   Executive Director
#
#                     ...             num_tl_90g_dpd_24m num_tl_op_past_12m  \
# id                  ...
# 68615044            ...                            0.0                0.0
# 68466066            ...                            0.0                4.0
# 68565856            ...                            0.0                1.0
# 68597047            ...                            0.0                4.0
# 68356421            ...                            0.0                3.0
#
#           pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies tax_liens  \
# id
# 68615044            73.7             25.0                  0.0       2.0
# 68466066           100.0             25.0                  1.0       0.0
# 68565856           100.0             33.3                  0.0       0.0
# 68597047            94.1            100.0                  0.0       0.0
# 68356421            97.0             25.0                  0.0       0.0
#
#          tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# id
# 68615044        704224.0          112166.0         5100.0
# 68466066         84627.0           43224.0        17800.0
# 68565856         69818.0           14118.0        15500.0
# 68597047         94620.0           48159.0         7500.0
# 68356421        436841.0          184356.0        21000.0
#
#          total_il_high_credit_limit
# id
# 68615044                   124120.0
# 68466066                    64227.0
# 68565856                    16318.0
# 68597047                    36720.0
# 68356421                   191682.0
#
# [5 rows x 110 columns]

# %%
list(loandata.columns.values)
# Out:
# ['member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit']

# %%
loandata.describe(include='all')
# Out:
#            member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count   4.210950e+05  421095.000000  421095.000000    421095.000000
# unique           NaN            NaN            NaN              NaN
# top              NaN            NaN            NaN              NaN
# freq             NaN            NaN            NaN              NaN
# mean    5.759576e+07   15240.285862   15240.285862     15234.156307
# std     1.013358e+07    8571.325901    8571.325901      8567.935724
# min     7.082500e+04    1000.000000    1000.000000       900.000000
# 25%     4.922617e+07    8500.000000    8500.000000      8500.000000
# 50%     5.895358e+07   14000.000000   14000.000000     14000.000000
# 75%     6.604584e+07   20000.000000   20000.000000     20000.000000
# max     7.354484e+07   35000.000000   35000.000000     35000.000000
#
#               term int_rate    installment   grade sub_grade emp_title  \
# count       421095   421095  421095.000000  421095    421095    397221
# unique           2      110            NaN       7        35    120812
# top      36 months    7.89%            NaN       C        C1   Teacher
# freq        283173    20309            NaN  120567     26434      8070
# mean           NaN      NaN     441.868902     NaN       NaN       NaN
# std            NaN      NaN     244.855262     NaN       NaN       NaN
# min            NaN      NaN      30.120000     NaN       NaN       NaN
# 25%            NaN      NaN     263.930000     NaN       NaN       NaN
# 50%            NaN      NaN     385.410000     NaN       NaN       NaN
# 75%            NaN      NaN     578.790000     NaN       NaN       NaN
# max            NaN      NaN    1445.460000     NaN       NaN       NaN
#
#                   ...             num_tl_90g_dpd_24m num_tl_op_past_12m  \
# count             ...                  421095.000000      421095.000000
# unique            ...                            NaN                NaN
# top               ...                            NaN                NaN
# freq              ...                            NaN                NaN
# mean              ...                       0.094318           2.170947
# std               ...                       0.522758           1.853858
# min               ...                       0.000000           0.000000
# 25%               ...                       0.000000           1.000000
# 50%               ...                       0.000000           2.000000
# 75%               ...                       0.000000           3.000000
# max               ...                      39.000000          30.000000
#
#         pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies      tax_liens  \
# count    421095.000000    416856.000000        421095.000000  421095.000000
# unique             NaN              NaN                  NaN            NaN
# top                NaN              NaN                  NaN            NaN
# freq               NaN              NaN                  NaN            NaN
# mean         93.924313        47.527110             0.133188       0.064556
# std           8.875399        36.054458             0.385975       0.444231
# min           0.000000         0.000000             0.000000       0.000000
# 25%          90.900000        15.400000             0.000000       0.000000
# 50%          97.400000        50.000000             0.000000       0.000000
# 75%         100.000000        75.000000             0.000000       0.000000
# max         100.000000       100.000000            11.000000      85.000000
#
#        tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# count     4.210950e+05      4.210950e+05  421095.000000
# unique             NaN               NaN            NaN
# top                NaN               NaN            NaN
# freq               NaN               NaN            NaN
# mean      1.734070e+05      5.222199e+04   21958.208958
# std       1.756722e+05      4.907494e+04   21840.371112
# min       2.500000e+03      0.000000e+00       0.000000
# 25%       5.090900e+04      2.259850e+04    7800.000000
# 50%       1.114050e+05      3.959600e+04   15200.000000
# 75%       2.496290e+05      6.565100e+04   28600.000000
# max       9.999999e+06      2.921551e+06  834300.000000
#
#        total_il_high_credit_limit
# count                4.210950e+05
# unique                        NaN
# top                           NaN
# freq                          NaN
# mean                 4.347865e+04
# std                  4.394271e+04
# min                  0.000000e+00
# 25%                  1.548150e+04
# 50%                  3.297000e+04
# 75%                  5.829900e+04
# max                  2.101913e+06
#
# [11 rows x 110 columns]

# %% [markdown]
# # Data understanding
#
# The reponse variable the learner will try to predict is the final loan_status, whether 'Fully Paid' or 'Charged Off' (i.e. severly delinquent and assess by the creditor as unlikly to be paid).
#
# ## Features to be used
#
# The features I'll consider to use in the learner are:
# * acc_open_past_24mths
# * addr_state
# * all_util
# * annual_inc
# * annual_inc_joint
# * application_type
# * avg_cur_bal
# * bc_open_to_buy
# * bc_util
# * chargeoff_within_12_mths
# * collection_recovery_fee
# * collections_12_mths_ex_med
# * delinq_2yrs
# * delinq_amnt
# * dti
# * dti_joint
# * earliest_cr_line
# * emp_length
# * emp_title
# * fico_range_high
# * fico_range_low
# * funded_amnt
# * funded_amnt_inv
# * grade
# * home_ownership
# * il_util
# * initial_list_status
# * inq_fi
# * inq_last_12m
# * inq_last_6mths
# * installment
# * int_rate
# * last_credit_pull_d
# * last_fico_range_high
# * last_fico_range_low
# * last_pymnt_amnt
# * last_pymnt_d
# * loan_amnt
# * max_bal_bc
# * member_id
# * mo_sin_old_il_acct
# * mo_sin_old_rev_tl_op
# * mo_sin_rcnt_rev_tl_op
# * mo_sin_rcnt_tl
# * mort_acc
# * mths_since_last_delinq
# * mths_since_last_major_derog
# * mths_since_last_record
# * mths_since_rcnt_il
# * mths_since_recent_bc
# * mths_since_recent_bc_dlq
# * mths_since_recent_inq
# * mths_since_recent_revol_delinq
# * num_accts_ever_120_pd
# * num_actv_bc_tl
# * num_actv_rev_tl
# * num_bc_sats
# * num_bc_tl
# * num_il_tl
# * num_op_rev_tl
# * num_rev_accts
# * num_rev_tl_bal_gt_0
# * num_sats
# * num_tl_120dpd_2m
# * num_tl_30dpd
# * num_tl_90g_dpd_24m
# * num_tl_op_past_12m
# * open_acc
# * open_acc_6m
# * open_il_12m
# * open_il_24m
# * open_il_6m
# * open_rv_12m
# * open_rv_24m
# * out_prncp
# * out_prncp_inv
# * pct_tl_nvr_dlq
# * percent_bc_gt_75
# * policy_code
# * pub_rec
# * pub_rec_bankruptcies
# * purpose
# * pymnt_plan
# * recoveries
# * revol_bal
# * revol_util
# * sub_grade
# * tax_liens
# * term
# * tot_coll_amt
# * tot_cur_bal
# * tot_hi_cred_lim
# * total_acc
# * total_bal_ex_mort
# * total_bal_il
# * total_bc_limit
# * total_cu_tl
# * total_il_high_credit_limit
# * total_pymnt
# * total_pymnt_inv
# * total_rec_int
# * total_rec_late_fee
# * total_rec_prncp
# * total_rev_hi_lim
# * verification_status
# * verified_status_joint
#
# The above list of features is prior to any approaches to reduce the number of dimensions

# %%
print loandata.loan_status.value_counts()
# For the project I'll limit the scopr to just looking at loan_status of 'Fully Paid' and 'Charged Off'
# Out:
# Current               363006
# Fully Paid             39008
# Charged Off             7512
# Late (31-120 days)      6233
# In Grace Period         3937
# Late (16-30 days)       1263
# Default                  136
# Name: loan_status, dtype: int64

# %%
completedloans=loandata[(loandata.loan_status=='Charged Off')|(loandata.loan_status=='Fully Paid')]

# %%
# Split into test and training sets. Allocating 80% for training data
random.seed(1234)
traindata, testdata = train_test_split(completedloans, test_size = 0.2)
# Out:
# 37216
# 9304

# %%
# Check for collinearity between variables
traindata.corr(method="pearson")
# Out:
#                                 member_id  loan_amnt  funded_amnt  \
# member_id                        1.000000  -0.006343    -0.006343
# loan_amnt                       -0.006343   1.000000     1.000000
# funded_amnt                     -0.006343   1.000000     1.000000
# funded_amnt_inv                 -0.006657   0.999996     0.999996
# installment                     -0.014994   0.951760     0.951760
# annual_inc                       0.025435   0.259030     0.259030
# dti                              0.004076  -0.005965    -0.005965
# delinq_2yrs                      0.003059  -0.014183    -0.014183
# inq_last_6mths                   0.015102  -0.011193    -0.011193
# mths_since_last_delinq           0.006166  -0.040377    -0.040377
# mths_since_last_record          -0.047345   0.022248     0.022248
# open_acc                         0.007510   0.186643     0.186643
# pub_rec                         -0.001351  -0.106076    -0.106076
# revol_bal                       -0.003608   0.327387     0.327387
# total_acc                        0.008594   0.190767     0.190767
# out_prncp                             NaN        NaN          NaN
# out_prncp_inv                         NaN        NaN          NaN
# total_pymnt                      0.034782   0.812078     0.812078
# total_pymnt_inv                  0.034520   0.812065     0.812065
# total_rec_prncp                  0.071961   0.772955     0.772955
# total_rec_int                   -0.269471   0.634180     0.634180
# total_rec_late_fee              -0.026993   0.050386     0.050386
# recoveries                      -0.114901   0.120564     0.120564
# collection_recovery_fee         -0.117524   0.123681     0.123681
# last_pymnt_amnt                  0.131113   0.687650     0.687650
# collections_12_mths_ex_med       0.012198  -0.021733    -0.021733
# mths_since_last_major_derog      0.010914  -0.004288    -0.004288
# policy_code                           NaN        NaN          NaN
# annual_inc_joint                -0.438684   0.912232     0.912232
# dti_joint                        0.146288  -0.328895    -0.328895
# ...                                   ...        ...          ...
# mo_sin_old_rev_tl_op             0.009030   0.148979     0.148979
# mo_sin_rcnt_rev_tl_op            0.001434   0.047363     0.047363
# mo_sin_rcnt_tl                  -0.010673   0.027234     0.027234
# mort_acc                         0.003905   0.205733     0.205733
# mths_since_recent_bc             0.004839   0.024090     0.024090
# mths_since_recent_bc_dlq        -0.006410  -0.052458    -0.052458
# mths_since_recent_inq           -0.030387  -0.016835    -0.016835
# mths_since_recent_revol_delinq  -0.003036  -0.049015    -0.049015
# num_accts_ever_120_pd           -0.009587  -0.053403    -0.053403
# num_actv_bc_tl                  -0.026075   0.214242     0.214242
# num_actv_rev_tl                 -0.030046   0.162818     0.162818
# num_bc_sats                      0.012318   0.221514     0.221514
# num_bc_tl                       -0.007644   0.193342     0.193342
# num_il_tl                        0.007733   0.069256     0.069256
# num_op_rev_tl                    0.006518   0.174482     0.174482
# num_rev_accts                    0.005078   0.160720     0.160720
# num_rev_tl_bal_gt_0             -0.035598   0.168091     0.168091
# num_sats                         0.006685   0.188204     0.188204
# num_tl_120dpd_2m                 0.004412  -0.000643    -0.000643
# num_tl_30dpd                     0.000834   0.007472     0.007472
# num_tl_90g_dpd_24m              -0.002124  -0.032784    -0.032784
# num_tl_op_past_12m               0.039958  -0.015067    -0.015067
# pct_tl_nvr_dlq                  -0.001038   0.099001     0.099001
# percent_bc_gt_75                -0.070764   0.022604     0.022604
# pub_rec_bankruptcies             0.004465  -0.132755    -0.132755
# tax_liens                        0.000864   0.005429     0.005429
# tot_hi_cred_lim                  0.029304   0.349651     0.349651
# total_bal_ex_mort                0.007877   0.286345     0.286345
# total_bc_limit                   0.034161   0.390682     0.390682
# total_il_high_credit_limit       0.017717   0.197028     0.197028
#
#                                 funded_amnt_inv  installment  annual_inc  \
# member_id                             -0.006657    -0.014994    0.025435
# loan_amnt                              0.999996     0.951760    0.259030
# funded_amnt                            0.999996     0.951760    0.259030
# funded_amnt_inv                        1.000000     0.951761    0.259041
# installment                            0.951761     1.000000    0.251069
# annual_inc                             0.259041     0.251069    1.000000
# dti                                   -0.005977    -0.006148   -0.031775
# delinq_2yrs                           -0.014203    -0.006311    0.055675
# inq_last_6mths                        -0.011251     0.020482    0.023554
# mths_since_last_delinq                -0.040344    -0.039113   -0.041766
# mths_since_last_record                 0.022319     0.009260   -0.087354
# open_acc                               0.186668     0.173550    0.090387
# pub_rec                               -0.106045    -0.088406   -0.021498
# revol_bal                              0.327342     0.311968    0.229027
# total_acc                              0.190804     0.171836    0.125154
# out_prncp                                   NaN          NaN         NaN
# out_prncp_inv                               NaN          NaN         NaN
# total_pymnt                            0.812093     0.770959    0.236240
# total_pymnt_inv                        0.812087     0.770948    0.236247
# total_rec_prncp                        0.772961     0.733718    0.232029
# total_rec_int                          0.634265     0.599295    0.131736
# total_rec_late_fee                     0.050352     0.061043    0.005523
# recoveries                             0.120570     0.119667    0.010125
# collection_recovery_fee                0.123680     0.124759    0.009398
# last_pymnt_amnt                        0.687626     0.637265    0.208285
# collections_12_mths_ex_med            -0.021774    -0.017695   -0.008464
# mths_since_last_major_derog           -0.004279    -0.001832   -0.028373
# policy_code                                 NaN          NaN         NaN
# annual_inc_joint                       0.912561     0.844332    0.845824
# dti_joint                             -0.330287    -0.533836   -0.262550
# ...                                         ...          ...         ...
# mo_sin_old_rev_tl_op                   0.149025     0.130560    0.101875
# mo_sin_rcnt_rev_tl_op                  0.047391     0.029524    0.032546
# mo_sin_rcnt_tl                         0.027249     0.011969   -0.011692
# mort_acc                               0.205758     0.182622    0.174092
# mths_since_recent_bc                   0.024123     0.008979    0.026353
# mths_since_recent_bc_dlq              -0.052442    -0.044182   -0.033943
# mths_since_recent_inq                 -0.016771    -0.035679   -0.040622
# mths_since_recent_revol_delinq        -0.048959    -0.043314   -0.028844
# num_accts_ever_120_pd                 -0.053435    -0.041077    0.016379
# num_actv_bc_tl                         0.214235     0.210111    0.071111
# num_actv_rev_tl                        0.162801     0.165223    0.041489
# num_bc_sats                            0.221535     0.210835    0.083321
# num_bc_tl                              0.193374     0.178958    0.091087
# num_il_tl                              0.069271     0.056147    0.069174
# num_op_rev_tl                          0.174508     0.166114    0.050186
# num_rev_accts                          0.160751     0.150529    0.070584
# num_rev_tl_bal_gt_0                    0.168081     0.168726    0.041873
# num_sats                               0.188229     0.174613    0.090697
# num_tl_120dpd_2m                      -0.000649     0.000550    0.008261
# num_tl_30dpd                           0.007472     0.010853    0.005938
# num_tl_90g_dpd_24m                    -0.032784    -0.025809    0.008499
# num_tl_op_past_12m                    -0.015137     0.014064    0.038244
# pct_tl_nvr_dlq                         0.099056     0.081737   -0.012785
# percent_bc_gt_75                       0.022538     0.034266   -0.014952
# pub_rec_bankruptcies                  -0.132727    -0.118298   -0.046847
# tax_liens                              0.005441     0.013553    0.027406
# tot_hi_cred_lim                        0.349694     0.319128    0.344938
# total_bal_ex_mort                      0.286340     0.270356    0.265976
# total_bc_limit                         0.390754     0.354537    0.220446
# total_il_high_credit_limit             0.197047     0.182299    0.214640
#
#                                      dti  delinq_2yrs  inq_last_6mths  \
# member_id                       0.004076     0.003059        0.015102
# loan_amnt                      -0.005965    -0.014183       -0.011193
# funded_amnt                    -0.005965    -0.014183       -0.011193
# funded_amnt_inv                -0.005977    -0.014203       -0.011251
# installment                    -0.006148    -0.006311        0.020482
# annual_inc                     -0.031775     0.055675        0.023554
# dti                             1.000000     0.005586        0.000858
# delinq_2yrs                     0.005586     1.000000        0.027896
# inq_last_6mths                  0.000858     0.027896        1.000000
# mths_since_last_delinq         -0.006650    -0.556884        0.032366
# mths_since_last_record          0.086488    -0.108764       -0.105174
# open_acc                        0.042181     0.029304        0.164701
# pub_rec                        -0.011722    -0.009980        0.110171
# revol_bal                       0.018903    -0.031601       -0.010313
# total_acc                       0.030716     0.106825        0.162564
# out_prncp                            NaN          NaN             NaN
# out_prncp_inv                        NaN          NaN             NaN
# total_pymnt                    -0.016299    -0.020570       -0.032283
# total_pymnt_inv                -0.016309    -0.020581       -0.032325
# total_rec_prncp                -0.018148    -0.022808       -0.039491
# total_rec_int                   0.006575     0.008648        0.036337
# total_rec_late_fee              0.001454     0.010877        0.012610
# recoveries                      0.006851     0.006768        0.029798
# collection_recovery_fee         0.007255     0.007791        0.030331
# last_pymnt_amnt                -0.015034    -0.024949       -0.028204
# collections_12_mths_ex_med     -0.001379     0.069293        0.014794
# mths_since_last_major_derog    -0.011423    -0.412973        0.041066
# policy_code                          NaN          NaN             NaN
# annual_inc_joint               -0.428935    -0.427092       -0.633392
# dti_joint                       0.505312     0.503869        0.190672
# ...                                  ...          ...             ...
# mo_sin_old_rev_tl_op            0.020355     0.078302        0.010536
# mo_sin_rcnt_rev_tl_op          -0.007358     0.039177       -0.211680
# mo_sin_rcnt_tl                 -0.017699     0.034289       -0.222329
# mort_acc                       -0.014276     0.065610        0.017279
# mths_since_recent_bc            0.010031     0.056697       -0.153374
# mths_since_recent_bc_dlq       -0.012722    -0.480430        0.059213
# mths_since_recent_inq           0.000081    -0.020825       -0.535145
# mths_since_recent_revol_delinq -0.010628    -0.509097        0.053810
# num_accts_ever_120_pd          -0.010556     0.190357        0.051000
# num_actv_bc_tl                  0.022596    -0.049718        0.105157
# num_actv_rev_tl                 0.041530    -0.013580        0.166590
# num_bc_sats                     0.009535    -0.031887        0.167882
# num_bc_tl                       0.006161     0.027029        0.149469
# num_il_tl                       0.035760     0.070065        0.056468
# num_op_rev_tl                   0.025964    -0.008900        0.179230
# num_rev_accts                   0.017096     0.074459        0.183302
# num_rev_tl_bal_gt_0             0.042148    -0.021519        0.141367
# num_sats                        0.042144     0.026144        0.160080
# num_tl_120dpd_2m               -0.002859     0.041211        0.006116
# num_tl_30dpd                    0.001112     0.095089        0.000737
# num_tl_90g_dpd_24m              0.005003     0.670559        0.045175
# num_tl_op_past_12m              0.010311    -0.024954        0.359991
# pct_tl_nvr_dlq                  0.014193    -0.433154       -0.047033
# percent_bc_gt_75                0.025945    -0.017096       -0.077146
# pub_rec_bankruptcies           -0.008586    -0.034206        0.128446
# tax_liens                      -0.006067     0.021567        0.018773
# tot_hi_cred_lim                -0.006640     0.054088        0.002066
# total_bal_ex_mort               0.043034     0.020348        0.026176
# total_bc_limit                 -0.003096    -0.077633        0.007985
# total_il_high_credit_limit      0.049162     0.048889        0.034151
#
#                                 mths_since_last_delinq  \
# member_id                                     0.006166
# loan_amnt                                    -0.040377
# funded_amnt                                  -0.040377
# funded_amnt_inv                              -0.040344
# installment                                  -0.039113
# annual_inc                                   -0.041766
# dti                                          -0.006650
# delinq_2yrs                                  -0.556884
# inq_last_6mths                                0.032366
# mths_since_last_delinq                        1.000000
# mths_since_last_record                       -0.031206
# open_acc                                     -0.028433
# pub_rec                                       0.122260
# revol_bal                                    -0.038776
# total_acc                                    -0.029589
# out_prncp                                          NaN
# out_prncp_inv                                      NaN
# total_pymnt                                  -0.016000
# total_pymnt_inv                              -0.015977
# total_rec_prncp                              -0.012044
# total_rec_int                                -0.034011
# total_rec_late_fee                           -0.018168
# recoveries                                   -0.014746
# collection_recovery_fee                      -0.014419
# last_pymnt_amnt                               0.001349
# collections_12_mths_ex_med                   -0.041183
# mths_since_last_major_derog                   0.702567
# policy_code                                        NaN
# annual_inc_joint                              1.000000
# dti_joint                                    -1.000000
# ...                                                ...
# mo_sin_old_rev_tl_op                         -0.034170
# mo_sin_rcnt_rev_tl_op                        -0.076959
# mo_sin_rcnt_tl                               -0.074602
# mort_acc                                     -0.056704
# mths_since_recent_bc                         -0.092625
# mths_since_recent_bc_dlq                      0.777844
# mths_since_recent_inq                        -0.016332
# mths_since_recent_revol_delinq                0.868904
# num_accts_ever_120_pd                         0.026184
# num_actv_bc_tl                                0.036766
# num_actv_rev_tl                               0.029992
# num_bc_sats                                   0.035029
# num_bc_tl                                     0.031300
# num_il_tl                                    -0.014121
# num_op_rev_tl                                -0.000462
# num_rev_accts                                -0.011518
# num_rev_tl_bal_gt_0                           0.022422
# num_sats                                     -0.027786
# num_tl_120dpd_2m                             -0.063920
# num_tl_30dpd                                 -0.120856
# num_tl_90g_dpd_24m                           -0.225301
# num_tl_op_past_12m                            0.103180
# pct_tl_nvr_dlq                                0.172983
# percent_bc_gt_75                              0.006744
# pub_rec_bankruptcies                          0.165576
# tax_liens                                    -0.000437
# tot_hi_cred_lim                              -0.103445
# total_bal_ex_mort                            -0.036963
# total_bc_limit                               -0.032898
# total_il_high_credit_limit                   -0.036793
#
#                                            ...              \
# member_id                                  ...
# loan_amnt                                  ...
# funded_amnt                                ...
# funded_amnt_inv                            ...
# installment                                ...
# annual_inc                                 ...
# dti                                        ...
# delinq_2yrs                                ...
# inq_last_6mths                             ...
# mths_since_last_delinq                     ...
# mths_since_last_record                     ...
# open_acc                                   ...
# pub_rec                                    ...
# revol_bal                                  ...
# total_acc                                  ...
# out_prncp                                  ...
# out_prncp_inv                              ...
# total_pymnt                                ...
# total_pymnt_inv                            ...
# total_rec_prncp                            ...
# total_rec_int                              ...
# total_rec_late_fee                         ...
# recoveries                                 ...
# collection_recovery_fee                    ...
# last_pymnt_amnt                            ...
# collections_12_mths_ex_med                 ...
# mths_since_last_major_derog                ...
# policy_code                                ...
# annual_inc_joint                           ...
# dti_joint                                  ...
# ...                                        ...
# mo_sin_old_rev_tl_op                       ...
# mo_sin_rcnt_rev_tl_op                      ...
# mo_sin_rcnt_tl                             ...
# mort_acc                                   ...
# mths_since_recent_bc                       ...
# mths_since_recent_bc_dlq                   ...
# mths_since_recent_inq                      ...
# mths_since_recent_revol_delinq             ...
# num_accts_ever_120_pd                      ...
# num_actv_bc_tl                             ...
# num_actv_rev_tl                            ...
# num_bc_sats                                ...
# num_bc_tl                                  ...
# num_il_tl                                  ...
# num_op_rev_tl                              ...
# num_rev_accts                              ...
# num_rev_tl_bal_gt_0                        ...
# num_sats                                   ...
# num_tl_120dpd_2m                           ...
# num_tl_30dpd                               ...
# num_tl_90g_dpd_24m                         ...
# num_tl_op_past_12m                         ...
# pct_tl_nvr_dlq                             ...
# percent_bc_gt_75                           ...
# pub_rec_bankruptcies                       ...
# tax_liens                                  ...
# tot_hi_cred_lim                            ...
# total_bal_ex_mort                          ...
# total_bc_limit                             ...
# total_il_high_credit_limit                 ...
#
#                                 num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# member_id                                -0.002124            0.039958
# loan_amnt                                -0.032784           -0.015067
# funded_amnt                              -0.032784           -0.015067
# funded_amnt_inv                          -0.032784           -0.015137
# installment                              -0.025809            0.014064
# annual_inc                                0.008499            0.038244
# dti                                       0.005003            0.010311
# delinq_2yrs                               0.670559           -0.024954
# inq_last_6mths                            0.045175            0.359991
# mths_since_last_delinq                   -0.225301            0.103180
# mths_since_last_record                   -0.115254           -0.055307
# open_acc                                 -0.005294            0.366903
# pub_rec                                   0.019636            0.104401
# revol_bal                                -0.044232           -0.028853
# total_acc                                 0.067096            0.352047
# out_prncp                                      NaN                 NaN
# out_prncp_inv                                  NaN                 NaN
# total_pymnt                              -0.031508           -0.024994
# total_pymnt_inv                          -0.031507           -0.025046
# total_rec_prncp                          -0.031941           -0.029546
# total_rec_int                            -0.008003            0.029380
# total_rec_late_fee                        0.003635            0.002488
# recoveries                               -0.001090            0.007076
# collection_recovery_fee                  -0.000556            0.008679
# last_pymnt_amnt                          -0.030479           -0.014290
# collections_12_mths_ex_med                0.107042            0.004917
# mths_since_last_major_derog              -0.440146            0.089235
# policy_code                                    NaN                 NaN
# annual_inc_joint                         -0.427092           -0.124101
# dti_joint                                 0.503869           -0.267638
# ...                                            ...                 ...
# mo_sin_old_rev_tl_op                      0.035050            0.007798
# mo_sin_rcnt_rev_tl_op                     0.015410           -0.395347
# mo_sin_rcnt_tl                            0.011859           -0.464666
# mort_acc                                  0.034293            0.048044
# mths_since_recent_bc                      0.018559           -0.290085
# mths_since_recent_bc_dlq                 -0.155187            0.123980
# mths_since_recent_inq                    -0.028813           -0.269281
# mths_since_recent_revol_delinq           -0.141896            0.114656
# num_accts_ever_120_pd                     0.271194            0.081017
# num_actv_bc_tl                           -0.034304            0.164922
# num_actv_rev_tl                          -0.013351            0.260294
# num_bc_sats                              -0.004673            0.246688
# num_bc_tl                                 0.024230            0.257864
# num_il_tl                                 0.052135            0.193938
# num_op_rev_tl                            -0.033220            0.360004
# num_rev_accts                             0.041119            0.327890
# num_rev_tl_bal_gt_0                      -0.029710            0.247433
# num_sats                                 -0.008891            0.364626
# num_tl_120dpd_2m                          0.075694           -0.005127
# num_tl_30dpd                              0.001797           -0.011284
# num_tl_90g_dpd_24m                        1.000000            0.008405
# num_tl_op_past_12m                        0.008405            1.000000
# pct_tl_nvr_dlq                           -0.271867            0.015490
# percent_bc_gt_75                         -0.016721           -0.170907
# pub_rec_bankruptcies                      0.023391            0.120640
# tax_liens                                 0.000385            0.011107
# tot_hi_cred_lim                          -0.005192            0.051035
# total_bal_ex_mort                        -0.003575            0.102096
# total_bc_limit                           -0.064907            0.041821
# total_il_high_credit_limit                0.016467            0.124964
#
#                                 pct_tl_nvr_dlq  percent_bc_gt_75  \
# member_id                            -0.001038         -0.070764
# loan_amnt                             0.099001          0.022604
# funded_amnt                           0.099001          0.022604
# funded_amnt_inv                       0.099056          0.022538
# installment                           0.081737          0.034266
# annual_inc                           -0.012785         -0.014952
# dti                                   0.014193          0.025945
# delinq_2yrs                          -0.433154         -0.017096
# inq_last_6mths                       -0.047033         -0.077146
# mths_since_last_delinq                0.172983          0.006744
# mths_since_last_record                0.222017          0.072617
# open_acc                              0.123843         -0.089254
# pub_rec                              -0.064665         -0.062133
# revol_bal                             0.120195          0.134902
# total_acc                             0.021790         -0.085517
# out_prncp                                  NaN               NaN
# out_prncp_inv                              NaN               NaN
# total_pymnt                           0.077746         -0.021268
# total_pymnt_inv                       0.077784         -0.021328
# total_rec_prncp                       0.077499         -0.036509
# total_rec_int                         0.027588          0.111547
# total_rec_late_fee                   -0.009021          0.025906
# recoveries                            0.009882          0.041549
# collection_recovery_fee               0.008481          0.043359
# last_pymnt_amnt                       0.067724         -0.024349
# collections_12_mths_ex_med           -0.046411         -0.028614
# mths_since_last_major_derog           0.104020          0.023707
# policy_code                                NaN               NaN
# annual_inc_joint                      0.343173          0.109110
# dti_joint                            -0.006327          0.037260
# ...                                        ...               ...
# mo_sin_old_rev_tl_op                 -0.096981         -0.004308
# mo_sin_rcnt_rev_tl_op                -0.036182          0.109470
# mo_sin_rcnt_tl                       -0.033796          0.103924
# mort_acc                             -0.045000         -0.007975
# mths_since_recent_bc                 -0.050102          0.131876
# mths_since_recent_bc_dlq              0.067185          0.004065
# mths_since_recent_inq                 0.021173          0.076734
# mths_since_recent_revol_delinq        0.076198          0.008096
# num_accts_ever_120_pd                -0.559333         -0.047687
# num_actv_bc_tl                        0.121954          0.074513
# num_actv_rev_tl                       0.080335          0.123664
# num_bc_sats                           0.119533         -0.153470
# num_bc_tl                             0.033894         -0.163240
# num_il_tl                             0.025985          0.014270
# num_op_rev_tl                         0.138952         -0.140833
# num_rev_accts                         0.022129         -0.133150
# num_rev_tl_bal_gt_0                   0.100427          0.131832
# num_sats                              0.128316         -0.089074
# num_tl_120dpd_2m                     -0.027782         -0.013984
# num_tl_30dpd                         -0.035112         -0.021760
# num_tl_90g_dpd_24m                   -0.271867         -0.016721
# num_tl_op_past_12m                    0.015490         -0.170907
# pct_tl_nvr_dlq                        1.000000         -0.003226
# percent_bc_gt_75                     -0.003226          1.000000
# pub_rec_bankruptcies                 -0.017909         -0.066527
# tax_liens                            -0.037818         -0.014444
# tot_hi_cred_lim                       0.035727         -0.000362
# total_bal_ex_mort                     0.080173          0.069389
# total_bc_limit                        0.221792         -0.188869
# total_il_high_credit_limit            0.028036          0.013097
#
#                                 pub_rec_bankruptcies  tax_liens  \
# member_id                                   0.004465   0.000864
# loan_amnt                                  -0.132755   0.005429
# funded_amnt                                -0.132755   0.005429
# funded_amnt_inv                            -0.132727   0.005441
# installment                                -0.118298   0.013553
# annual_inc                                 -0.046847   0.027406
# dti                                        -0.008586  -0.006067
# delinq_2yrs                                -0.034206   0.021567
# inq_last_6mths                              0.128446   0.018773
# mths_since_last_delinq                      0.165576  -0.000437
# mths_since_last_record                      0.156380  -0.257505
# open_acc                                   -0.027045  -0.011940
# pub_rec                                     0.717313   0.614140
# revol_bal                                  -0.139164  -0.021229
# total_acc                                   0.071399  -0.027612
# out_prncp                                        NaN        NaN
# out_prncp_inv                                    NaN        NaN
# total_pymnt                                -0.104067  -0.009824
# total_pymnt_inv                            -0.104052  -0.009821
# total_rec_prncp                            -0.101449  -0.012587
# total_rec_int                              -0.060248   0.013997
# total_rec_late_fee                         -0.012982   0.012950
# recoveries                                 -0.011861   0.012765
# collection_recovery_fee                    -0.011162   0.013581
# last_pymnt_amnt                            -0.085907  -0.015060
# collections_12_mths_ex_med                  0.002400   0.032229
# mths_since_last_major_derog                 0.147591   0.016162
# policy_code                                      NaN        NaN
# annual_inc_joint                            0.215301        NaN
# dti_joint                                  -0.520456        NaN
# ...                                              ...        ...
# mo_sin_old_rev_tl_op                        0.077357   0.007556
# mo_sin_rcnt_rev_tl_op                      -0.087696  -0.002601
# mo_sin_rcnt_tl                             -0.079034  -0.008112
# mort_acc                                    0.038170  -0.003295
# mths_since_recent_bc                       -0.060108  -0.000270
# mths_since_recent_bc_dlq                    0.188888   0.012199
# mths_since_recent_inq                      -0.081109  -0.009018
# mths_since_recent_revol_delinq              0.180967   0.002252
# num_accts_ever_120_pd                       0.006700   0.009769
# num_actv_bc_tl                             -0.075581   0.007289
# num_actv_rev_tl                            -0.015686   0.002953
# num_bc_sats                                -0.040432  -0.004876
# num_bc_tl                                   0.051659  -0.018653
# num_il_tl                                   0.002603  -0.016543
# num_op_rev_tl                               0.004892  -0.006425
# num_rev_accts                               0.094437  -0.025319
# num_rev_tl_bal_gt_0                        -0.033038   0.003069
# num_sats                                   -0.035761  -0.011801
# num_tl_120dpd_2m                            0.000002  -0.004387
# num_tl_30dpd                               -0.015186   0.005761
# num_tl_90g_dpd_24m                          0.023391   0.000385
# num_tl_op_past_12m                          0.120640   0.011107
# pct_tl_nvr_dlq                             -0.017909  -0.037818
# percent_bc_gt_75                           -0.066527  -0.014444
# pub_rec_bankruptcies                        1.000000   0.033230
# tax_liens                                   0.033230   1.000000
# tot_hi_cred_lim                            -0.130325   0.004122
# total_bal_ex_mort                          -0.092683  -0.003827
# total_bc_limit                             -0.177611  -0.030976
# total_il_high_credit_limit                 -0.040170   0.009349
#
#                                 tot_hi_cred_lim  total_bal_ex_mort  \
# member_id                              0.029304           0.007877
# loan_amnt                              0.349651           0.286345
# funded_amnt                            0.349651           0.286345
# funded_amnt_inv                        0.349694           0.286340
# installment                            0.319128           0.270356
# annual_inc                             0.344938           0.265976
# dti                                   -0.006640           0.043034
# delinq_2yrs                            0.054088           0.020348
# inq_last_6mths                         0.002066           0.026176
# mths_since_last_delinq                -0.103445          -0.036963
# mths_since_last_record                 0.016713          -0.006717
# open_acc                               0.262111           0.379219
# pub_rec                               -0.099316          -0.078630
# revol_bal                              0.480799           0.507918
# total_acc                              0.302472           0.407780
# out_prncp                                   NaN                NaN
# out_prncp_inv                               NaN                NaN
# total_pymnt                            0.342384           0.239091
# total_pymnt_inv                        0.342421           0.239093
# total_rec_prncp                        0.338821           0.229545
# total_rec_int                          0.180234           0.171948
# total_rec_late_fee                    -0.001887           0.006492
# recoveries                            -0.005407           0.029038
# collection_recovery_fee               -0.007198           0.030019
# last_pymnt_amnt                        0.311861           0.207547
# collections_12_mths_ex_med            -0.015939          -0.019415
# mths_since_last_major_derog           -0.051064          -0.023671
# policy_code                                 NaN                NaN
# annual_inc_joint                       0.629572           0.513701
# dti_joint                             -0.291744           0.457880
# ...                                         ...                ...
# mo_sin_old_rev_tl_op                   0.200810           0.089351
# mo_sin_rcnt_rev_tl_op                  0.042750           0.016813
# mo_sin_rcnt_tl                        -0.039437          -0.070980
# mort_acc                               0.511841           0.126358
# mths_since_recent_bc                   0.053343           0.025617
# mths_since_recent_bc_dlq              -0.070243          -0.028057
# mths_since_recent_inq                 -0.049662          -0.041166
# mths_since_recent_revol_delinq        -0.068294          -0.030666
# num_accts_ever_120_pd                 -0.000008          -0.003850
# num_actv_bc_tl                         0.128696           0.142882
# num_actv_rev_tl                        0.114618           0.134144
# num_bc_sats                            0.157447           0.124653
# num_bc_tl                              0.165482           0.111021
# num_il_tl                              0.164600           0.505443
# num_op_rev_tl                          0.133503           0.118118
# num_rev_accts                          0.161553           0.106594
# num_rev_tl_bal_gt_0                    0.117502           0.142802
# num_sats                               0.263272           0.380976
# num_tl_120dpd_2m                       0.006892          -0.001287
# num_tl_30dpd                           0.021006           0.003936
# num_tl_90g_dpd_24m                    -0.005192          -0.003575
# num_tl_op_past_12m                     0.051035           0.102096
# pct_tl_nvr_dlq                         0.035727           0.080173
# percent_bc_gt_75                      -0.000362           0.069389
# pub_rec_bankruptcies                  -0.130325          -0.092683
# tax_liens                              0.004122          -0.003827
# tot_hi_cred_lim                        1.000000           0.509163
# total_bal_ex_mort                      0.509163           1.000000
# total_bc_limit                         0.399009           0.270856
# total_il_high_credit_limit             0.372814           0.865598
#
#                                 total_bc_limit  total_il_high_credit_limit
# member_id                             0.034161                    0.017717
# loan_amnt                             0.390682                    0.197028
# funded_amnt                           0.390682                    0.197028
# funded_amnt_inv                       0.390754                    0.197047
# installment                           0.354537                    0.182299
# annual_inc                            0.220446                    0.214640
# dti                                  -0.003096                    0.049162
# delinq_2yrs                          -0.077633                    0.048889
# inq_last_6mths                        0.007985                    0.034151
# mths_since_last_delinq               -0.032898                   -0.036793
# mths_since_last_record               -0.001282                   -0.011462
# open_acc                              0.345826                    0.337594
# pub_rec                              -0.166128                   -0.028192
# revol_bal                             0.476499                    0.089295
# total_acc                             0.249894                    0.402213
# out_prncp                                  NaN                         NaN
# out_prncp_inv                              NaN                         NaN
# total_pymnt                           0.361917                    0.162017
# total_pymnt_inv                       0.361977                    0.162035
# total_rec_prncp                       0.362563                    0.155306
# total_rec_int                         0.137438                    0.116634
# total_rec_late_fee                   -0.004869                    0.004260
# recoveries                            0.008046                    0.022868
# collection_recovery_fee               0.000621                    0.024482
# last_pymnt_amnt                       0.315884                    0.144580
# collections_12_mths_ex_med           -0.030380                   -0.007936
# mths_since_last_major_derog          -0.009422                   -0.024364
# policy_code                                NaN                         NaN
# annual_inc_joint                      0.629790                    0.539261
# dti_joint                             0.236937                    0.409621
# ...                                        ...                         ...
# mo_sin_old_rev_tl_op                  0.247922                    0.012138
# mo_sin_rcnt_rev_tl_op                -0.028815                    0.008465
# mo_sin_rcnt_tl                       -0.001802                   -0.101961
# mort_acc                              0.191926                    0.078870
# mths_since_recent_bc                 -0.085928                    0.007487
# mths_since_recent_bc_dlq             -0.103963                   -0.016356
# mths_since_recent_inq                -0.006333                   -0.048860
# mths_since_recent_revol_delinq       -0.090488                   -0.021561
# num_accts_ever_120_pd                -0.134793                    0.033494
# num_actv_bc_tl                        0.452020                    0.020566
# num_actv_rev_tl                       0.266233                    0.015099
# num_bc_sats                           0.580891                    0.025290
# num_bc_tl                             0.471683                    0.041443
# num_il_tl                            -0.029777                    0.584484
# num_op_rev_tl                         0.408610                    0.029318
# num_rev_accts                         0.338906                    0.041884
# num_rev_tl_bal_gt_0                   0.269272                    0.020957
# num_sats                              0.348017                    0.339415
# num_tl_120dpd_2m                     -0.005834                   -0.003603
# num_tl_30dpd                          0.009689                    0.004106
# num_tl_90g_dpd_24m                   -0.064907                    0.016467
# num_tl_op_past_12m                    0.041821                    0.124964
# pct_tl_nvr_dlq                        0.221792                    0.028036
# percent_bc_gt_75                     -0.188869                    0.013097
# pub_rec_bankruptcies                 -0.177611                   -0.040170
# tax_liens                            -0.030976                    0.009349
# tot_hi_cred_lim                       0.399009                    0.372814
# total_bal_ex_mort                     0.270856                    0.865598
# total_bc_limit                        1.000000                    0.088947
# total_il_high_credit_limit            0.088947                    1.000000
#
# [85 rows x 85 columns]

# %% [markdown]
# ## Some visualisations

# %%
#loandata.boxplot(column='loan_amnt',by='loan_status')
traindata.boxplot(column='loan_amnt',by='loan_status')

# We can observe that loans that resulted in being charged off had a higher median loan amount

# %%
traindata.boxplot(column='annual_inc',by='loan_status')

# Hard to see, but it looks like annual income would be a good predictor to include
# Need to find a way to make the y a log scale

# %%
#
traindata.int_rate = pd.Series(traindata.int_rate).str.replace('%', '').astype(float)
traindata.boxplot(column='int_rate',by='loan_status')

# As this boxplot shows, higher interest rates would make a loan more expensive to service
# Out:
# C:\Users\New\Anaconda2\lib\site-packages\pandas\core\generic.py:2698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
