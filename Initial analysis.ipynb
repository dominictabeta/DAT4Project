# %%
# %matplotlib inline

import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
import random

# %%
loandata = pd.read_csv('../data/LoanStats3d.csv',skiprows=[0] ,index_col='id')
# Out:
# C:\Users\Dom\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
loandata.head()
# Out:
#            member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 68426699  73316523.0    20000.0      20000.0          20000.0   36 months
# 67275481  72077199.0    20000.0      20000.0          20000.0   36 months
# 68446771  73336594.0     7200.0       7200.0           7200.0   36 months
# 68615044  73517819.0    16000.0      16000.0          16000.0   60 months
# 68466995  73356835.0    10000.0      10000.0          10000.0   36 months
#
#          int_rate  installment grade sub_grade  \
# id
# 68426699    6.49%       612.89     A        A2
# 67275481    8.49%       631.26     B        B1
# 68446771   15.77%       252.32     D        D1
# 68615044   13.99%       372.21     C        C4
# 68466995    7.91%       312.95     A        A5
#
#                                         emp_title            ...              \
# id                                                           ...
# 68426699              TEAM LEAD, QUALITY ENGINEER            ...
# 67275481                              road driver            ...
# 68446771  Bank Officer Senior Customer Care Spec.            ...
# 68615044                         Registered Nurse            ...
# 68466995                                  Teacher            ...
#
#          num_tl_90g_dpd_24m num_tl_op_past_12m  pct_tl_nvr_dlq  \
# id
# 68426699                0.0                2.0            95.7
# 67275481                1.0                0.0            93.3
# 68446771                0.0                3.0            97.7
# 68615044                0.0                0.0            73.7
# 68466995                0.0                1.0           100.0
#
#          percent_bc_gt_75 pub_rec_bankruptcies tax_liens tot_hi_cred_lim  \
# id
# 68426699              0.0                  0.0       0.0        247433.0
# 67275481              0.0                  0.0       0.0        193390.0
# 68446771             50.0                  0.0       1.0        255047.0
# 68615044             25.0                  0.0       2.0        704224.0
# 68466995              0.0                  0.0       0.0         35247.0
#
#          total_bal_ex_mort total_bc_limit total_il_high_credit_limit
# id
# 68426699           41663.0        12700.0                    46367.0
# 67275481           27937.0        14500.0                    36144.0
# 68446771          275831.0         6700.0                   246447.0
# 68615044          112166.0         5100.0                   124120.0
# 68466995           27354.0        13000.0                    20447.0
#
# [5 rows x 110 columns]

# %%
list(loandata.columns.values)
# Out:
# ['member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit']

# %%
loandata.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 421097 entries, 68426699 to Total amount funded in policy code 2: 1944088810
# Data columns (total 110 columns):
# member_id                         float64
# loan_amnt                         float64
# funded_amnt                       float64
# funded_amnt_inv                   float64
# term                              object
# int_rate                          object
# installment                       float64
# grade                             object
# sub_grade                         object
# emp_title                         object
# emp_length                        object
# home_ownership                    object
# annual_inc                        float64
# verification_status               object
# issue_d                           object
# loan_status                       object
# pymnt_plan                        object
# url                               object
# desc                              object
# purpose                           object
# title                             object
# zip_code                          object
# addr_state                        object
# dti                               float64
# delinq_2yrs                       float64
# earliest_cr_line                  object
# inq_last_6mths                    float64
# mths_since_last_delinq            float64
# mths_since_last_record            float64
# open_acc                          float64
# pub_rec                           float64
# revol_bal                         float64
# revol_util                        object
# total_acc                         float64
# initial_list_status               object
# out_prncp                         float64
# out_prncp_inv                     float64
# total_pymnt                       float64
# total_pymnt_inv                   float64
# total_rec_prncp                   float64
# total_rec_int                     float64
# total_rec_late_fee                float64
# recoveries                        float64
# collection_recovery_fee           float64
# last_pymnt_d                      object
# last_pymnt_amnt                   float64
# next_pymnt_d                      object
# last_credit_pull_d                object
# collections_12_mths_ex_med        float64
# mths_since_last_major_derog       float64
# policy_code                       float64
# application_type                  object
# annual_inc_joint                  float64
# dti_joint                         float64
# verification_status_joint         object
# acc_now_delinq                    float64
# tot_coll_amt                      float64
# tot_cur_bal                       float64
# open_acc_6m                       float64
# open_il_6m                        float64
# open_il_12m                       float64
# open_il_24m                       float64
# mths_since_rcnt_il                float64
# total_bal_il                      float64
# il_util                           float64
# open_rv_12m                       float64
# open_rv_24m                       float64
# max_bal_bc                        float64
# all_util                          float64
# total_rev_hi_lim                  float64
# inq_fi                            float64
# total_cu_tl                       float64
# inq_last_12m                      float64
# acc_open_past_24mths              float64
# avg_cur_bal                       float64
# bc_open_to_buy                    float64
# bc_util                           float64
# chargeoff_within_12_mths          float64
# delinq_amnt                       float64
# mo_sin_old_il_acct                float64
# mo_sin_old_rev_tl_op              float64
# mo_sin_rcnt_rev_tl_op             float64
# mo_sin_rcnt_tl                    float64
# mort_acc                          float64
# mths_since_recent_bc              float64
# mths_since_recent_bc_dlq          float64
# mths_since_recent_inq             float64
# mths_since_recent_revol_delinq    float64
# num_accts_ever_120_pd             float64
# num_actv_bc_tl                    float64
# num_actv_rev_tl                   float64
# num_bc_sats                       float64
# num_bc_tl                         float64
# num_il_tl                         float64
# num_op_rev_tl                     float64
# num_rev_accts                     float64
# num_rev_tl_bal_gt_0               float64
# num_sats                          float64
# num_tl_120dpd_2m                  float64
# num_tl_30dpd                      float64
# num_tl_90g_dpd_24m                float64
# num_tl_op_past_12m                float64
# pct_tl_nvr_dlq                    float64
# percent_bc_gt_75                  float64
# pub_rec_bankruptcies              float64
# tax_liens                         float64
# tot_hi_cred_lim                   float64
# total_bal_ex_mort                 float64
# total_bc_limit                    float64
# total_il_high_credit_limit        float64
# dtypes: float64(85), object(25)
# memory usage: 356.6+ MB

# %%
loandata.describe(include='all')
# Out:
#            member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count   4.210950e+05  421095.000000  421095.000000    421095.000000
# unique           NaN            NaN            NaN              NaN
# top              NaN            NaN            NaN              NaN
# freq             NaN            NaN            NaN              NaN
# mean    5.759576e+07   15240.285862   15240.285862     15234.156307
# std     1.013358e+07    8571.325901    8571.325901      8567.935724
# min     7.082500e+04    1000.000000    1000.000000       900.000000
# 25%     4.922617e+07    8500.000000    8500.000000      8500.000000
# 50%     5.895358e+07   14000.000000   14000.000000     14000.000000
# 75%     6.604584e+07   20000.000000   20000.000000     20000.000000
# max     7.354484e+07   35000.000000   35000.000000     35000.000000
#
#               term int_rate    installment   grade sub_grade emp_title  \
# count       421095   421095  421095.000000  421095    421095    397221
# unique           2      110            NaN       7        35    120812
# top      36 months    7.89%            NaN       C        C1   Teacher
# freq        283173    20310            NaN  120567     26434      8070
# mean           NaN      NaN     441.870837     NaN       NaN       NaN
# std            NaN      NaN     244.856460     NaN       NaN       NaN
# min            NaN      NaN      30.120000     NaN       NaN       NaN
# 25%            NaN      NaN     263.930000     NaN       NaN       NaN
# 50%            NaN      NaN     385.420000     NaN       NaN       NaN
# 75%            NaN      NaN     578.790000     NaN       NaN       NaN
# max            NaN      NaN    1445.460000     NaN       NaN       NaN
#
#                   ...             num_tl_90g_dpd_24m num_tl_op_past_12m  \
# count             ...                  421095.000000      421095.000000
# unique            ...                            NaN                NaN
# top               ...                            NaN                NaN
# freq              ...                            NaN                NaN
# mean              ...                       0.094318           2.170947
# std               ...                       0.522758           1.853858
# min               ...                       0.000000           0.000000
# 25%               ...                       0.000000           1.000000
# 50%               ...                       0.000000           2.000000
# 75%               ...                       0.000000           3.000000
# max               ...                      39.000000          30.000000
#
#         pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies      tax_liens  \
# count    421095.000000    416856.000000        421095.000000  421095.000000
# unique             NaN              NaN                  NaN            NaN
# top                NaN              NaN                  NaN            NaN
# freq               NaN              NaN                  NaN            NaN
# mean         93.924313        47.527110             0.133188       0.064556
# std           8.875399        36.054458             0.385975       0.444231
# min           0.000000         0.000000             0.000000       0.000000
# 25%          90.900000        15.400000             0.000000       0.000000
# 50%          97.400000        50.000000             0.000000       0.000000
# 75%         100.000000        75.000000             0.000000       0.000000
# max         100.000000       100.000000            11.000000      85.000000
#
#        tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# count     4.210950e+05      4.210950e+05  421095.000000
# unique             NaN               NaN            NaN
# top                NaN               NaN            NaN
# freq               NaN               NaN            NaN
# mean      1.734070e+05      5.222199e+04   21958.208958
# std       1.756722e+05      4.907494e+04   21840.371112
# min       2.500000e+03      0.000000e+00       0.000000
# 25%       5.090900e+04      2.259850e+04    7800.000000
# 50%       1.114050e+05      3.959600e+04   15200.000000
# 75%       2.496290e+05      6.565100e+04   28600.000000
# max       9.999999e+06      2.921551e+06  834300.000000
#
#        total_il_high_credit_limit
# count                4.210950e+05
# unique                        NaN
# top                           NaN
# freq                          NaN
# mean                 4.347865e+04
# std                  4.394271e+04
# min                  0.000000e+00
# 25%                  1.548150e+04
# 50%                  3.297000e+04
# 75%                  5.829900e+04
# max                  2.101913e+06
#
# [11 rows x 110 columns]

# %% [markdown]
# # Data understanding
#
# The reponse variable the learner will try to predict is the final loan_status, whether 'Fully Paid' or 'Charged Off' (i.e. severly delinquent and assess by the creditor as unlikly to be paid).
#
# ## Features to be used
#
# The features I'll consider to use in the learner are:
# * acc_open_past_24mths
# * addr_state
# * all_util
# * annual_inc
# * annual_inc_joint
# * application_type
# * avg_cur_bal
# * bc_open_to_buy
# * bc_util
# * chargeoff_within_12_mths
# * collection_recovery_fee
# * collections_12_mths_ex_med
# * delinq_2yrs
# * delinq_amnt
# * dti
# * dti_joint
# * earliest_cr_line
# * emp_length
# * emp_title
# * fico_range_high
# * fico_range_low
# * funded_amnt
# * funded_amnt_inv
# * grade
# * home_ownership
# * il_util
# * initial_list_status
# * inq_fi
# * inq_last_12m
# * inq_last_6mths
# * installment
# * int_rate
# * last_credit_pull_d
# * last_fico_range_high
# * last_fico_range_low
# * last_pymnt_amnt
# * last_pymnt_d
# * loan_amnt
# * max_bal_bc
# * member_id
# * mo_sin_old_il_acct
# * mo_sin_old_rev_tl_op
# * mo_sin_rcnt_rev_tl_op
# * mo_sin_rcnt_tl
# * mort_acc
# * mths_since_last_delinq
# * mths_since_last_major_derog
# * mths_since_last_record
# * mths_since_rcnt_il
# * mths_since_recent_bc
# * mths_since_recent_bc_dlq
# * mths_since_recent_inq
# * mths_since_recent_revol_delinq
# * num_accts_ever_120_pd
# * num_actv_bc_tl
# * num_actv_rev_tl
# * num_bc_sats
# * num_bc_tl
# * num_il_tl
# * num_op_rev_tl
# * num_rev_accts
# * num_rev_tl_bal_gt_0
# * num_sats
# * num_tl_120dpd_2m
# * num_tl_30dpd
# * num_tl_90g_dpd_24m
# * num_tl_op_past_12m
# * open_acc
# * open_acc_6m
# * open_il_12m
# * open_il_24m
# * open_il_6m
# * open_rv_12m
# * open_rv_24m
# * out_prncp
# * out_prncp_inv
# * pct_tl_nvr_dlq
# * percent_bc_gt_75
# * policy_code
# * pub_rec
# * pub_rec_bankruptcies
# * purpose
# * pymnt_plan
# * recoveries
# * revol_bal
# * revol_util
# * sub_grade
# * tax_liens
# * term
# * tot_coll_amt
# * tot_cur_bal
# * tot_hi_cred_lim
# * total_acc
# * total_bal_ex_mort
# * total_bal_il
# * total_bc_limit
# * total_cu_tl
# * total_il_high_credit_limit
# * total_pymnt
# * total_pymnt_inv
# * total_rec_int
# * total_rec_late_fee
# * total_rec_prncp
# * total_rev_hi_lim
# * verification_status
# * verified_status_joint
#
# The above list of features is prior to any approaches to reduce the number of dimensions

# %%
print loandata.loan_status.value_counts()
# For the project I'll limit the scopr to just looking at loan_status of 'Fully Paid' and 'Charged Off'
# Out:
# Current               371168
# Fully Paid             34061
# Charged Off             6011
# Late (31-120 days)      5648
# In Grace Period         2828
# Late (16-30 days)       1251
# Default                  128
# Name: loan_status, dtype: int64

# %%
completedloans=loandata[(loandata.loan_status=='Charged Off')|(loandata.loan_status=='Fully Paid')]

# %%
# Split into test and training sets. Allocating 80% for training data
random.seed(1234)
traindata, testdata = train_test_split(completedloans, test_size = 0.2)

# %%
# Check for collinearity between variables
traindata.corr(method="pearson")
# Out:
#                                 member_id  loan_amnt  funded_amnt  \
# member_id                        1.000000  -0.001585    -0.001585
# loan_amnt                       -0.001585   1.000000     1.000000
# funded_amnt                     -0.001585   1.000000     1.000000
# funded_amnt_inv                 -0.001894   0.999996     0.999996
# installment                     -0.007640   0.951990     0.951990
# annual_inc                       0.029365   0.266633     0.266633
# dti                             -0.035756  -0.001576    -0.001576
# delinq_2yrs                     -0.005220  -0.018262    -0.018262
# inq_last_6mths                   0.004171  -0.017467    -0.017467
# mths_since_last_delinq           0.006478  -0.043969    -0.043969
# mths_since_last_record          -0.031863   0.014118     0.014118
# open_acc                         0.002657   0.183813     0.183813
# pub_rec                         -0.003070  -0.109631    -0.109631
# revol_bal                       -0.000072   0.328865     0.328865
# total_acc                        0.000539   0.189108     0.189108
# out_prncp                             NaN        NaN          NaN
# out_prncp_inv                         NaN        NaN          NaN
# total_pymnt                      0.048990   0.821084     0.821084
# total_pymnt_inv                  0.048725   0.821072     0.821072
# total_rec_prncp                  0.085347   0.786979     0.786979
# total_rec_int                   -0.274441   0.627136     0.627136
# total_rec_late_fee              -0.031488   0.040656     0.040656
# recoveries                      -0.110692   0.105579     0.105579
# collection_recovery_fee         -0.115729   0.112401     0.112401
# last_pymnt_amnt                  0.139755   0.704050     0.704050
# collections_12_mths_ex_med       0.012439  -0.019635    -0.019635
# mths_since_last_major_derog      0.012612  -0.010724    -0.010724
# policy_code                           NaN        NaN          NaN
# annual_inc_joint                -0.263171   0.547941     0.547941
# dti_joint                       -0.214474  -0.241259    -0.241259
# ...                                   ...        ...          ...
# mo_sin_old_rev_tl_op             0.002493   0.155369     0.155369
# mo_sin_rcnt_rev_tl_op            0.005630   0.042876     0.042876
# mo_sin_rcnt_tl                  -0.002965   0.025336     0.025336
# mort_acc                        -0.004483   0.212669     0.212669
# mths_since_recent_bc             0.004933   0.026445     0.026445
# mths_since_recent_bc_dlq        -0.000442  -0.048576    -0.048576
# mths_since_recent_inq           -0.027564  -0.017688    -0.017688
# mths_since_recent_revol_delinq   0.001976  -0.048166    -0.048166
# num_accts_ever_120_pd           -0.012007  -0.051152    -0.051152
# num_actv_bc_tl                  -0.026015   0.211341     0.211341
# num_actv_rev_tl                 -0.030802   0.161114     0.161114
# num_bc_sats                      0.011343   0.218787     0.218787
# num_bc_tl                       -0.011886   0.188796     0.188796
# num_il_tl                        0.002379   0.067301     0.067301
# num_op_rev_tl                    0.005338   0.170891     0.170891
# num_rev_accts                   -0.000147   0.158485     0.158485
# num_rev_tl_bal_gt_0             -0.036213   0.165082     0.165082
# num_sats                         0.001812   0.185303     0.185303
# num_tl_120dpd_2m                 0.008884   0.007038     0.007038
# num_tl_30dpd                     0.015429   0.008593     0.008593
# num_tl_90g_dpd_24m              -0.004607  -0.032358    -0.032358
# num_tl_op_past_12m               0.035067  -0.014118    -0.014118
# pct_tl_nvr_dlq                   0.003757   0.103512     0.103512
# percent_bc_gt_75                -0.067023   0.027483     0.027483
# pub_rec_bankruptcies             0.006440  -0.135928    -0.135928
# tax_liens                       -0.003554   0.003594     0.003594
# tot_hi_cred_lim                  0.027686   0.350520     0.350520
# total_bal_ex_mort                0.009819   0.286148     0.286148
# total_bc_limit                   0.035758   0.383148     0.383148
# total_il_high_credit_limit       0.017872   0.195461     0.195461
#
#                                 funded_amnt_inv  installment  annual_inc  \
# member_id                             -0.001894    -0.007640    0.029365
# loan_amnt                              0.999996     0.951990    0.266633
# funded_amnt                            0.999996     0.951990    0.266633
# funded_amnt_inv                        1.000000     0.951991    0.266642
# installment                            0.951991     1.000000    0.256765
# annual_inc                             0.266642     0.256765    1.000000
# dti                                   -0.001654    -0.000649   -0.170675
# delinq_2yrs                           -0.018284    -0.008891    0.058322
# inq_last_6mths                        -0.017530     0.015231    0.017017
# mths_since_last_delinq                -0.043940    -0.041961   -0.044837
# mths_since_last_record                 0.014184     0.000133   -0.069196
# open_acc                               0.183824     0.172410    0.091899
# pub_rec                               -0.109601    -0.092402   -0.026096
# revol_bal                              0.328853     0.314841    0.235874
# total_acc                              0.189143     0.171526    0.124982
# out_prncp                                   NaN          NaN         NaN
# out_prncp_inv                               NaN          NaN         NaN
# total_pymnt                            0.821086     0.780519    0.244891
# total_pymnt_inv                        0.821080     0.780508    0.244897
# total_rec_prncp                        0.786971     0.748056    0.241358
# total_rec_int                          0.627225     0.594146    0.136236
# total_rec_late_fee                     0.040665     0.049245    0.004163
# recoveries                             0.105596     0.103726    0.006932
# collection_recovery_fee                0.112411     0.112375    0.005485
# last_pymnt_amnt                        0.704015     0.654572    0.217940
# collections_12_mths_ex_med            -0.019694    -0.015892   -0.008153
# mths_since_last_major_derog           -0.010704    -0.010940   -0.026783
# policy_code                                 NaN          NaN         NaN
# annual_inc_joint                       0.548889     0.444234    0.822249
# dti_joint                             -0.244935    -0.416616   -0.292386
# ...                                         ...          ...         ...
# mo_sin_old_rev_tl_op                   0.155408     0.137786    0.106940
# mo_sin_rcnt_rev_tl_op                  0.042903     0.025620    0.031726
# mo_sin_rcnt_tl                         0.025350     0.010161   -0.012414
# mort_acc                               0.212691     0.190877    0.176557
# mths_since_recent_bc                   0.026481     0.010399    0.023185
# mths_since_recent_bc_dlq              -0.048577    -0.037878   -0.037726
# mths_since_recent_inq                 -0.017621    -0.035433   -0.038721
# mths_since_recent_revol_delinq        -0.048125    -0.038901   -0.033251
# num_accts_ever_120_pd                 -0.051180    -0.038725    0.019087
# num_actv_bc_tl                         0.211332     0.208754    0.070141
# num_actv_rev_tl                        0.161091     0.165901    0.040371
# num_bc_sats                            0.218800     0.208156    0.083573
# num_bc_tl                              0.188835     0.173549    0.090686
# num_il_tl                              0.067311     0.056145    0.067678
# num_op_rev_tl                          0.170902     0.163889    0.051412
# num_rev_accts                          0.158519     0.148218    0.071157
# num_rev_tl_bal_gt_0                    0.165066     0.167974    0.040299
# num_sats                               0.185314     0.173375    0.092202
# num_tl_120dpd_2m                       0.007024     0.008734    0.013250
# num_tl_30dpd                           0.008603     0.011938    0.012708
# num_tl_90g_dpd_24m                    -0.032372    -0.023848    0.009671
# num_tl_op_past_12m                    -0.014183     0.016095    0.034719
# pct_tl_nvr_dlq                         0.103570     0.085545   -0.016507
# percent_bc_gt_75                       0.027408     0.040609   -0.015888
# pub_rec_bankruptcies                  -0.135900    -0.121865   -0.048015
# tax_liens                              0.003600     0.011170    0.023456
# tot_hi_cred_lim                        0.350556     0.320497    0.356366
# total_bal_ex_mort                      0.286158     0.270683    0.274830
# total_bc_limit                         0.383225     0.347106    0.229033
# total_il_high_credit_limit             0.195475     0.180916    0.220014
#
#                                      dti  delinq_2yrs  inq_last_6mths  \
# member_id                      -0.035756    -0.005220        0.004171
# loan_amnt                      -0.001576    -0.018262       -0.017467
# funded_amnt                    -0.001576    -0.018262       -0.017467
# funded_amnt_inv                -0.001654    -0.018284       -0.017530
# installment                    -0.000649    -0.008891        0.015231
# annual_inc                     -0.170675     0.058322        0.017017
# dti                             1.000000    -0.020297       -0.000780
# delinq_2yrs                    -0.020297     1.000000        0.030850
# inq_last_6mths                 -0.000780     0.030850        1.000000
# mths_since_last_delinq          0.008295    -0.545673        0.037272
# mths_since_last_record          0.081696    -0.099007       -0.100918
# open_acc                        0.274397     0.033822        0.164575
# pub_rec                        -0.059868    -0.016881        0.111324
# revol_bal                       0.117359    -0.027341       -0.011329
# total_acc                       0.200014     0.108183        0.163585
# out_prncp                            NaN          NaN             NaN
# out_prncp_inv                        NaN          NaN             NaN
# total_pymnt                    -0.056774    -0.025055       -0.034572
# total_pymnt_inv                -0.056837    -0.025069       -0.034618
# total_rec_prncp                -0.067950    -0.027373       -0.041410
# total_rec_int                   0.061860     0.010427        0.041585
# total_rec_late_fee              0.013404     0.008948        0.008027
# recoveries                      0.040493     0.003792        0.019655
# collection_recovery_fee         0.046440     0.003285        0.021978
# last_pymnt_amnt                -0.054229    -0.029638       -0.031362
# collections_12_mths_ex_med     -0.004684     0.070922        0.012725
# mths_since_last_major_derog     0.043430    -0.414486        0.054200
# policy_code                          NaN          NaN             NaN
# annual_inc_joint               -0.718730          NaN       -0.636690
# dti_joint                       0.495671          NaN        0.110496
# ...                                  ...          ...             ...
# mo_sin_old_rev_tl_op            0.025182     0.077526        0.009288
# mo_sin_rcnt_rev_tl_op          -0.031453     0.032707       -0.209716
# mo_sin_rcnt_tl                 -0.096476     0.028795       -0.218621
# mort_acc                       -0.076653     0.061820        0.014163
# mths_since_recent_bc           -0.010845     0.050832       -0.152961
# mths_since_recent_bc_dlq       -0.006521    -0.478353        0.061925
# mths_since_recent_inq           0.008065    -0.024450       -0.533329
# mths_since_recent_revol_delinq -0.012804    -0.505934        0.057938
# num_accts_ever_120_pd          -0.052279     0.190100        0.051863
# num_actv_bc_tl                  0.170915    -0.050044        0.107242
# num_actv_rev_tl                 0.254282    -0.012824        0.168413
# num_bc_sats                     0.097949    -0.031998        0.167014
# num_bc_tl                       0.056847     0.029282        0.150262
# num_il_tl                       0.218189     0.071917        0.058765
# num_op_rev_tl                   0.173420    -0.009841        0.176996
# num_rev_accts                   0.119049     0.076950        0.183542
# num_rev_tl_bal_gt_0             0.257901    -0.020472        0.142978
# num_sats                        0.273786     0.030563        0.159585
# num_tl_120dpd_2m               -0.017935     0.037455       -0.005366
# num_tl_30dpd                    0.007067     0.098615        0.003358
# num_tl_90g_dpd_24m             -0.021443     0.677727        0.048106
# num_tl_op_past_12m              0.086538    -0.021631        0.360670
# pct_tl_nvr_dlq                  0.101141    -0.429486       -0.051468
# percent_bc_gt_75                0.198845    -0.013223       -0.074311
# pub_rec_bankruptcies           -0.041509    -0.036656        0.127211
# tax_liens                      -0.033055     0.010345        0.019133
# tot_hi_cred_lim                -0.020835     0.052600       -0.004604
# total_bal_ex_mort               0.275970     0.019028        0.019485
# total_bc_limit                  0.006656    -0.076181        0.002041
# total_il_high_credit_limit      0.310714     0.046858        0.028710
#
#                                 mths_since_last_delinq  \
# member_id                                     0.006478
# loan_amnt                                    -0.043969
# funded_amnt                                  -0.043969
# funded_amnt_inv                              -0.043940
# installment                                  -0.041961
# annual_inc                                   -0.044837
# dti                                           0.008295
# delinq_2yrs                                  -0.545673
# inq_last_6mths                                0.037272
# mths_since_last_delinq                        1.000000
# mths_since_last_record                       -0.036326
# open_acc                                     -0.029763
# pub_rec                                       0.134187
# revol_bal                                    -0.038672
# total_acc                                    -0.022739
# out_prncp                                          NaN
# out_prncp_inv                                      NaN
# total_pymnt                                  -0.019927
# total_pymnt_inv                              -0.019908
# total_rec_prncp                              -0.015762
# total_rec_int                                -0.038997
# total_rec_late_fee                           -0.010679
# recoveries                                   -0.016113
# collection_recovery_fee                      -0.014594
# last_pymnt_amnt                              -0.004966
# collections_12_mths_ex_med                   -0.044504
# mths_since_last_major_derog                   0.706332
# policy_code                                        NaN
# annual_inc_joint                             -0.956940
# dti_joint                                     0.810585
# ...                                                ...
# mo_sin_old_rev_tl_op                         -0.029256
# mo_sin_rcnt_rev_tl_op                        -0.076947
# mo_sin_rcnt_tl                               -0.064524
# mort_acc                                     -0.052782
# mths_since_recent_bc                         -0.089646
# mths_since_recent_bc_dlq                      0.778180
# mths_since_recent_inq                        -0.010752
# mths_since_recent_revol_delinq                0.869786
# num_accts_ever_120_pd                         0.032836
# num_actv_bc_tl                                0.040762
# num_actv_rev_tl                               0.033392
# num_bc_sats                                   0.040677
# num_bc_tl                                     0.035434
# num_il_tl                                    -0.013239
# num_op_rev_tl                                 0.005343
# num_rev_accts                                -0.004720
# num_rev_tl_bal_gt_0                           0.024950
# num_sats                                     -0.029082
# num_tl_120dpd_2m                             -0.063985
# num_tl_30dpd                                 -0.129620
# num_tl_90g_dpd_24m                           -0.219301
# num_tl_op_past_12m                            0.098056
# pct_tl_nvr_dlq                                0.169439
# percent_bc_gt_75                              0.007865
# pub_rec_bankruptcies                          0.170288
# tax_liens                                     0.009229
# tot_hi_cred_lim                              -0.109308
# total_bal_ex_mort                            -0.040651
# total_bc_limit                               -0.031359
# total_il_high_credit_limit                   -0.041041
#
#                                            ...              \
# member_id                                  ...
# loan_amnt                                  ...
# funded_amnt                                ...
# funded_amnt_inv                            ...
# installment                                ...
# annual_inc                                 ...
# dti                                        ...
# delinq_2yrs                                ...
# inq_last_6mths                             ...
# mths_since_last_delinq                     ...
# mths_since_last_record                     ...
# open_acc                                   ...
# pub_rec                                    ...
# revol_bal                                  ...
# total_acc                                  ...
# out_prncp                                  ...
# out_prncp_inv                              ...
# total_pymnt                                ...
# total_pymnt_inv                            ...
# total_rec_prncp                            ...
# total_rec_int                              ...
# total_rec_late_fee                         ...
# recoveries                                 ...
# collection_recovery_fee                    ...
# last_pymnt_amnt                            ...
# collections_12_mths_ex_med                 ...
# mths_since_last_major_derog                ...
# policy_code                                ...
# annual_inc_joint                           ...
# dti_joint                                  ...
# ...                                        ...
# mo_sin_old_rev_tl_op                       ...
# mo_sin_rcnt_rev_tl_op                      ...
# mo_sin_rcnt_tl                             ...
# mort_acc                                   ...
# mths_since_recent_bc                       ...
# mths_since_recent_bc_dlq                   ...
# mths_since_recent_inq                      ...
# mths_since_recent_revol_delinq             ...
# num_accts_ever_120_pd                      ...
# num_actv_bc_tl                             ...
# num_actv_rev_tl                            ...
# num_bc_sats                                ...
# num_bc_tl                                  ...
# num_il_tl                                  ...
# num_op_rev_tl                              ...
# num_rev_accts                              ...
# num_rev_tl_bal_gt_0                        ...
# num_sats                                   ...
# num_tl_120dpd_2m                           ...
# num_tl_30dpd                               ...
# num_tl_90g_dpd_24m                         ...
# num_tl_op_past_12m                         ...
# pct_tl_nvr_dlq                             ...
# percent_bc_gt_75                           ...
# pub_rec_bankruptcies                       ...
# tax_liens                                  ...
# tot_hi_cred_lim                            ...
# total_bal_ex_mort                          ...
# total_bc_limit                             ...
# total_il_high_credit_limit                 ...
#
#                                 num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# member_id                                -0.004607            0.035067
# loan_amnt                                -0.032358           -0.014118
# funded_amnt                              -0.032358           -0.014118
# funded_amnt_inv                          -0.032372           -0.014183
# installment                              -0.023848            0.016095
# annual_inc                                0.009671            0.034719
# dti                                      -0.021443            0.086538
# delinq_2yrs                               0.677727           -0.021631
# inq_last_6mths                            0.048106            0.360670
# mths_since_last_delinq                   -0.219301            0.098056
# mths_since_last_record                   -0.107179           -0.050708
# open_acc                                  0.000557            0.367645
# pub_rec                                   0.023141            0.109022
# revol_bal                                -0.039860           -0.026815
# total_acc                                 0.070381            0.351642
# out_prncp                                      NaN                 NaN
# out_prncp_inv                                  NaN                 NaN
# total_pymnt                              -0.033188           -0.017010
# total_pymnt_inv                          -0.033192           -0.017066
# total_rec_prncp                          -0.033805           -0.021679
# total_rec_int                            -0.007371            0.037002
# total_rec_late_fee                        0.006641            0.007212
# recoveries                               -0.000693            0.005344
# collection_recovery_fee                   0.000774            0.009055
# last_pymnt_amnt                          -0.035164           -0.006720
# collections_12_mths_ex_med                0.109634            0.008026
# mths_since_last_major_derog              -0.433721            0.092796
# policy_code                                    NaN                 NaN
# annual_inc_joint                               NaN            0.368757
# dti_joint                                      NaN           -0.311894
# ...                                            ...                 ...
# mo_sin_old_rev_tl_op                      0.035894            0.006173
# mo_sin_rcnt_rev_tl_op                     0.012251           -0.393428
# mo_sin_rcnt_tl                            0.010127           -0.458035
# mort_acc                                  0.032599            0.044780
# mths_since_recent_bc                      0.017376           -0.286763
# mths_since_recent_bc_dlq                 -0.161318            0.129056
# mths_since_recent_inq                    -0.027922           -0.263710
# mths_since_recent_revol_delinq           -0.145968            0.113450
# num_accts_ever_120_pd                     0.271062            0.076987
# num_actv_bc_tl                           -0.035103            0.166982
# num_actv_rev_tl                          -0.013661            0.264649
# num_bc_sats                              -0.002825            0.248812
# num_bc_tl                                 0.028538            0.253212
# num_il_tl                                 0.055846            0.195904
# num_op_rev_tl                            -0.033180            0.361918
# num_rev_accts                             0.043725            0.326587
# num_rev_tl_bal_gt_0                      -0.030327            0.251035
# num_sats                                 -0.003230            0.364951
# num_tl_120dpd_2m                          0.067667           -0.007695
# num_tl_30dpd                              0.005034           -0.007651
# num_tl_90g_dpd_24m                        1.000000            0.009642
# num_tl_op_past_12m                        0.009642            1.000000
# pct_tl_nvr_dlq                           -0.272559            0.014831
# percent_bc_gt_75                         -0.016352           -0.165742
# pub_rec_bankruptcies                      0.024753            0.119971
# tax_liens                                 0.001935            0.014100
# tot_hi_cred_lim                          -0.002595            0.046104
# total_bal_ex_mort                        -0.002195            0.098917
# total_bc_limit                           -0.063239            0.035093
# total_il_high_credit_limit                0.017080            0.119063
#
#                                 pct_tl_nvr_dlq  percent_bc_gt_75  \
# member_id                             0.003757         -0.067023
# loan_amnt                             0.103512          0.027483
# funded_amnt                           0.103512          0.027483
# funded_amnt_inv                       0.103570          0.027408
# installment                           0.085545          0.040609
# annual_inc                           -0.016507         -0.015888
# dti                                   0.101141          0.198845
# delinq_2yrs                          -0.429486         -0.013223
# inq_last_6mths                       -0.051468         -0.074311
# mths_since_last_delinq                0.169439          0.007865
# mths_since_last_record                0.215828          0.063942
# open_acc                              0.121776         -0.085592
# pub_rec                              -0.064804         -0.068541
# revol_bal                             0.119653          0.143010
# total_acc                             0.021494         -0.084668
# out_prncp                                  NaN               NaN
# out_prncp_inv                              NaN               NaN
# total_pymnt                           0.083759         -0.014179
# total_pymnt_inv                       0.083804         -0.014249
# total_rec_prncp                       0.083702         -0.027583
# total_rec_int                         0.027130          0.108922
# total_rec_late_fee                   -0.012216          0.023104
# recoveries                            0.013041          0.032399
# collection_recovery_fee               0.011641          0.037953
# last_pymnt_amnt                       0.074615         -0.017498
# collections_12_mths_ex_med           -0.044552         -0.025385
# mths_since_last_major_derog           0.107744          0.017172
# policy_code                                NaN               NaN
# annual_inc_joint                     -0.481654         -0.407823
# dti_joint                             0.325493          0.580671
# ...                                        ...               ...
# mo_sin_old_rev_tl_op                 -0.098266         -0.003012
# mo_sin_rcnt_rev_tl_op                -0.028793          0.118241
# mo_sin_rcnt_tl                       -0.035099          0.102855
# mort_acc                             -0.049045         -0.004470
# mths_since_recent_bc                 -0.044230          0.138489
# mths_since_recent_bc_dlq              0.066659          0.005454
# mths_since_recent_inq                 0.028380          0.074803
# mths_since_recent_revol_delinq        0.075017          0.007295
# num_accts_ever_120_pd                -0.559823         -0.045100
# num_actv_bc_tl                        0.122301          0.081814
# num_actv_rev_tl                       0.077606          0.129437
# num_bc_sats                           0.116139         -0.146462
# num_bc_tl                             0.032697         -0.160246
# num_il_tl                             0.030103          0.011391
# num_op_rev_tl                         0.135347         -0.135659
# num_rev_accts                         0.018846         -0.130248
# num_rev_tl_bal_gt_0                   0.098616          0.137801
# num_sats                              0.126251         -0.085537
# num_tl_120dpd_2m                     -0.026235         -0.017060
# num_tl_30dpd                         -0.034483         -0.029536
# num_tl_90g_dpd_24m                   -0.272559         -0.016352
# num_tl_op_past_12m                    0.014831         -0.165742
# pct_tl_nvr_dlq                        1.000000         -0.003071
# percent_bc_gt_75                     -0.003071          1.000000
# pub_rec_bankruptcies                 -0.019631         -0.068598
# tax_liens                            -0.032696         -0.017272
# tot_hi_cred_lim                       0.037770          0.004222
# total_bal_ex_mort                     0.084302          0.073841
# total_bc_limit                        0.223322         -0.180632
# total_il_high_credit_limit            0.032141          0.014311
#
#                                 pub_rec_bankruptcies  tax_liens  \
# member_id                                   0.006440  -0.003554
# loan_amnt                                  -0.135928   0.003594
# funded_amnt                                -0.135928   0.003594
# funded_amnt_inv                            -0.135900   0.003600
# installment                                -0.121865   0.011170
# annual_inc                                 -0.048015   0.023456
# dti                                        -0.041509  -0.033055
# delinq_2yrs                                -0.036656   0.010345
# inq_last_6mths                              0.127211   0.019133
# mths_since_last_delinq                      0.170288   0.009229
# mths_since_last_record                      0.150608  -0.242008
# open_acc                                   -0.025035  -0.009535
# pub_rec                                     0.725796   0.600960
# revol_bal                                  -0.141942  -0.023321
# total_acc                                   0.071690  -0.023996
# out_prncp                                        NaN        NaN
# out_prncp_inv                                    NaN        NaN
# total_pymnt                                -0.108812  -0.012663
# total_pymnt_inv                            -0.108795  -0.012660
# total_rec_prncp                            -0.106690  -0.014501
# total_rec_int                              -0.059464   0.012175
# total_rec_late_fee                         -0.006269   0.006071
# recoveries                                 -0.012488   0.001860
# collection_recovery_fee                    -0.010519   0.002800
# last_pymnt_amnt                            -0.092235  -0.016090
# collections_12_mths_ex_med                  0.008844   0.033978
# mths_since_last_major_derog                 0.153801   0.016157
# policy_code                                      NaN        NaN
# annual_inc_joint                            0.162009        NaN
# dti_joint                                  -0.472301        NaN
# ...                                              ...        ...
# mo_sin_old_rev_tl_op                        0.068348   0.005712
# mo_sin_rcnt_rev_tl_op                      -0.087031  -0.009012
# mo_sin_rcnt_tl                             -0.078201  -0.012142
# mort_acc                                    0.031750  -0.002195
# mths_since_recent_bc                       -0.059010  -0.008337
# mths_since_recent_bc_dlq                    0.199940   0.022712
# mths_since_recent_inq                      -0.081135  -0.008839
# mths_since_recent_revol_delinq              0.184825   0.012497
# num_accts_ever_120_pd                       0.004102   0.021230
# num_actv_bc_tl                             -0.071064   0.004236
# num_actv_rev_tl                            -0.012447  -0.000147
# num_bc_sats                                -0.036964  -0.006286
# num_bc_tl                                   0.052211  -0.019881
# num_il_tl                                   0.006472  -0.009367
# num_op_rev_tl                               0.004919  -0.006068
# num_rev_accts                               0.092019  -0.026695
# num_rev_tl_bal_gt_0                        -0.029622   0.000656
# num_sats                                   -0.033488  -0.009430
# num_tl_120dpd_2m                           -0.002957  -0.004407
# num_tl_30dpd                               -0.017109   0.006357
# num_tl_90g_dpd_24m                          0.024753   0.001935
# num_tl_op_past_12m                          0.119971   0.014100
# pct_tl_nvr_dlq                             -0.019631  -0.032696
# percent_bc_gt_75                           -0.068598  -0.017272
# pub_rec_bankruptcies                        1.000000   0.036518
# tax_liens                                   0.036518   1.000000
# tot_hi_cred_lim                            -0.131084  -0.001223
# total_bal_ex_mort                          -0.093640  -0.004780
# total_bc_limit                             -0.177346  -0.033676
# total_il_high_credit_limit                 -0.039447   0.006777
#
#                                 tot_hi_cred_lim  total_bal_ex_mort  \
# member_id                              0.027686           0.009819
# loan_amnt                              0.350520           0.286148
# funded_amnt                            0.350520           0.286148
# funded_amnt_inv                        0.350556           0.286158
# installment                            0.320497           0.270683
# annual_inc                             0.356366           0.274830
# dti                                   -0.020835           0.275970
# delinq_2yrs                            0.052600           0.019028
# inq_last_6mths                        -0.004604           0.019485
# mths_since_last_delinq                -0.109308          -0.040651
# mths_since_last_record                 0.012978          -0.012217
# open_acc                               0.254610           0.375201
# pub_rec                               -0.104309          -0.082863
# revol_bal                              0.485832           0.512428
# total_acc                              0.296071           0.403237
# out_prncp                                   NaN                NaN
# out_prncp_inv                               NaN                NaN
# total_pymnt                            0.343057           0.243181
# total_pymnt_inv                        0.343090           0.243189
# total_rec_prncp                        0.339907           0.235353
# total_rec_int                          0.187098           0.170676
# total_rec_late_fee                    -0.000535           0.009475
# recoveries                            -0.010912           0.019608
# collection_recovery_fee               -0.012031           0.022104
# last_pymnt_amnt                        0.314271           0.214471
# collections_12_mths_ex_med            -0.009926          -0.014423
# mths_since_last_major_derog           -0.054183          -0.021045
# policy_code                                 NaN                NaN
# annual_inc_joint                       0.144284           0.372380
# dti_joint                             -0.422425           0.530157
# ...                                         ...                ...
# mo_sin_old_rev_tl_op                   0.206591           0.091131
# mo_sin_rcnt_rev_tl_op                  0.041185           0.021554
# mo_sin_rcnt_tl                        -0.037057          -0.066442
# mort_acc                               0.508193           0.123386
# mths_since_recent_bc                   0.054674           0.028061
# mths_since_recent_bc_dlq              -0.079153          -0.040578
# mths_since_recent_inq                 -0.048355          -0.038770
# mths_since_recent_revol_delinq        -0.076417          -0.036737
# num_accts_ever_120_pd                 -0.001260          -0.006101
# num_actv_bc_tl                         0.122269           0.135420
# num_actv_rev_tl                        0.108667           0.125763
# num_bc_sats                            0.151151           0.121383
# num_bc_tl                              0.163862           0.108614
# num_il_tl                              0.158056           0.501490
# num_op_rev_tl                          0.125493           0.111910
# num_rev_accts                          0.159729           0.104570
# num_rev_tl_bal_gt_0                    0.110463           0.133338
# num_sats                               0.255453           0.376746
# num_tl_120dpd_2m                       0.009738          -0.001822
# num_tl_30dpd                           0.024652           0.012413
# num_tl_90g_dpd_24m                    -0.002595          -0.002195
# num_tl_op_past_12m                     0.046104           0.098917
# pct_tl_nvr_dlq                         0.037770           0.084302
# percent_bc_gt_75                       0.004222           0.073841
# pub_rec_bankruptcies                  -0.131084          -0.093640
# tax_liens                             -0.001223          -0.004780
# tot_hi_cred_lim                        1.000000           0.508251
# total_bal_ex_mort                      0.508251           1.000000
# total_bc_limit                         0.404438           0.276089
# total_il_high_credit_limit             0.367870           0.864459
#
#                                 total_bc_limit  total_il_high_credit_limit
# member_id                             0.035758                    0.017872
# loan_amnt                             0.383148                    0.195461
# funded_amnt                           0.383148                    0.195461
# funded_amnt_inv                       0.383225                    0.195475
# installment                           0.347106                    0.180916
# annual_inc                            0.229033                    0.220014
# dti                                   0.006656                    0.310714
# delinq_2yrs                          -0.076181                    0.046858
# inq_last_6mths                        0.002041                    0.028710
# mths_since_last_delinq               -0.031359                   -0.041041
# mths_since_last_record                0.013930                   -0.009402
# open_acc                              0.333840                    0.333566
# pub_rec                              -0.167733                   -0.032204
# revol_bal                             0.485271                    0.088874
# total_acc                             0.241985                    0.395873
# out_prncp                                  NaN                         NaN
# out_prncp_inv                              NaN                         NaN
# total_pymnt                           0.353760                    0.164204
# total_pymnt_inv                       0.353830                    0.164217
# total_rec_prncp                       0.355144                    0.158577
# total_rec_int                         0.129982                    0.114662
# total_rec_late_fee                   -0.006352                    0.004338
# recoveries                            0.009960                    0.018969
# collection_recovery_fee               0.000418                    0.021379
# last_pymnt_amnt                       0.315142                    0.148472
# collections_12_mths_ex_med           -0.033589                   -0.002764
# mths_since_last_major_derog          -0.011219                   -0.021281
# policy_code                                NaN                         NaN
# annual_inc_joint                      0.551986                    0.251577
# dti_joint                             0.330181                    0.627407
# ...                                        ...                         ...
# mo_sin_old_rev_tl_op                  0.252528                    0.011484
# mo_sin_rcnt_rev_tl_op                -0.020727                    0.008588
# mo_sin_rcnt_tl                        0.000183                   -0.096289
# mort_acc                              0.187297                    0.076420
# mths_since_recent_bc                 -0.080105                    0.007353
# mths_since_recent_bc_dlq             -0.103224                   -0.026200
# mths_since_recent_inq                -0.003729                   -0.045928
# mths_since_recent_revol_delinq       -0.090708                   -0.026916
# num_accts_ever_120_pd                -0.136802                    0.030435
# num_actv_bc_tl                        0.441020                    0.016284
# num_actv_rev_tl                       0.254131                    0.010996
# num_bc_sats                           0.566647                    0.022451
# num_bc_tl                             0.461074                    0.037789
# num_il_tl                            -0.031922                    0.577875
# num_op_rev_tl                         0.395500                    0.025261
# num_rev_accts                         0.331064                    0.039706
# num_rev_tl_bal_gt_0                   0.256830                    0.015561
# num_sats                              0.336221                    0.335074
# num_tl_120dpd_2m                     -0.002754                   -0.001377
# num_tl_30dpd                          0.013366                    0.010554
# num_tl_90g_dpd_24m                   -0.063239                    0.017080
# num_tl_op_past_12m                    0.035093                    0.119063
# pct_tl_nvr_dlq                        0.223322                    0.032141
# percent_bc_gt_75                     -0.180632                    0.014311
# pub_rec_bankruptcies                 -0.177346                   -0.039447
# tax_liens                            -0.033676                    0.006777
# tot_hi_cred_lim                       0.404438                    0.367870
# total_bal_ex_mort                     0.276089                    0.864459
# total_bc_limit                        1.000000                    0.089972
# total_il_high_credit_limit            0.089972                    1.000000
#
# [85 rows x 85 columns]

# %% [markdown]
# ## Some visualisations

# %%
#loandata.boxplot(column='loan_amnt',by='loan_status')
traindata.boxplot(column='loan_amnt',by='loan_status')

# We can observe that loans that resulted in being charged off had a higher median loan amount

# %%
traindata.boxplot(column='annual_inc',by='loan_status')

# Hard to see, but it looks like annual income would be a good predictor to include
# Need to find a way to make the y a log scale

# %%
#
traindata.int_rate = pd.Series(traindata.int_rate).str.replace('%', '').astype(float)
traindata.boxplot(column='int_rate',by='loan_status')

# As this boxplot shows, higher interest rates would make a loan more expensive to service

# %% [markdown]
# completedloans.acc_now_delinq.dtype

# %% [markdown]
# ## Selecting the features we need
# With 110 columns in our data set there's a bit of work involved in cleaning up the data set to something more manageable. We'll only keep the columns that have predictive power. I'll carry out this feature reduction looking at a subset of columns at a time.
#
# ### First Slice

# %%
traindata.ix[:3,:10]
# Out:
#            member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 63419398  67762228.0    12000.0      12000.0          11750.0   36 months
# 40522703  43387511.0    15000.0      15000.0          15000.0   36 months
# 50073829  53432570.0     9500.0       9500.0           9500.0   36 months
#
#           int_rate  installment grade sub_grade  \
# id
# 63419398     11.49       395.66     B        B5
# 40522703     12.99       505.34     C        C2
# 50073829      7.26       294.47     A        A4
#
#                                emp_title
# id
# 63419398  Senior Underwriting Asssistant
# 40522703                 Service Manager
# 50073829                   Warehouseman

# %%
traindata.ix[:3,:10].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 63419398 to 50073829
# Data columns (total 10 columns):
# member_id          3 non-null float64
# loan_amnt          3 non-null float64
# funded_amnt        3 non-null float64
# funded_amnt_inv    3 non-null float64
# term               3 non-null object
# int_rate           3 non-null float64
# installment        3 non-null float64
# grade              3 non-null object
# sub_grade          3 non-null object
# emp_title          3 non-null object
# dtypes: float64(6), object(4)
# memory usage: 264.0+ bytes

# %% [markdown]
# For this slice we can drop the member_id column as it provides no predictive usefulness. The column int_rate is originally an object type and we have already stripped out the '%' symbol and converted the column to a float type. The correlation matrix produced earlier indicates a correlation of 1 between loan_amnt and funded_amnt, meaning we can drop one of these columns with no loss in potential predictive power.

# %%
traindata.drop(['member_id','funded_amnt'],1,inplace=True)
#traindata.drop('id',1,inplace=True)
# Out:
# C:\Users\Dom\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
traindata.ix[:3,:7]
# Out:
#           loan_amnt  funded_amnt_inv        term  int_rate  installment grade  \
# id
# 56141172    18000.0          18000.0   60 months      9.99       382.36     B
# 38519759    18350.0          18350.0   36 months     19.24       674.87     E
# 55391689    12000.0          12000.0   60 months     20.99       324.58     E
#
#          sub_grade
# id
# 56141172        B3
# 38519759        E2
# 55391689        E5

# %% [markdown]
# ### Employment title

# %%
print traindata.emp_title.value_counts().head()
print traindata.emp_title.value_counts().tail()
traindata.emp_title.unique().shape
# Out:
# Manager             549
# Teacher             485
# Supervisor          232
# Sales               216
# Registered Nurse    206
# Name: emp_title, dtype: int64
# Whole body buyer              1
# Senior Business Technician    1
# CDL transport drivet          1
# Branch Mananger               1
# Business Service Tech         1
# Name: emp_title, dtype: int64
# (14918L,)

# %% [markdown]
# The above results yield 14918 unique entries for emp_title within a training set of 32057 entries, which makes it a stretch to expect predictive power from this column. This field appears to be free text, so we'll drop this column from the training set.

# %%
traindata.drop(['emp_title'],1,inplace=True)

# %%
traindata.ix[:3,:10]
# Out:
#           loan_amnt  funded_amnt_inv        term  int_rate  installment grade  \
# id
# 56141172    18000.0          18000.0   60 months      9.99       382.36     B
# 38519759    18350.0          18350.0   36 months     19.24       674.87     E
# 55391689    12000.0          12000.0   60 months     20.99       324.58     E
#
#          sub_grade emp_length home_ownership  annual_inc
# id
# 56141172        B3    8 years       MORTGAGE     90000.0
# 38519759        E2    8 years           RENT     50000.0
# 55391689        E5  10+ years       MORTGAGE    135000.0

# %%
### Employment Length

# %%
traindata.emp_length.value_counts()
# Out:
# 10+ years    10826
# 2 years       2954
# < 1 year      2661
# 3 years       2502
# 1 year        2161
# 4 years       1881
# 5 years       1817
# 8 years       1589
# n/a           1566
# 7 years       1491
# 6 years       1321
# 9 years       1288
# Name: emp_length, dtype: int64
